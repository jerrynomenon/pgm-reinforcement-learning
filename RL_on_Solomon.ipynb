# %%
# !pip install stable_baselines3
# !pip install ortools
# !pip install shimmy
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.4.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting gymnasium<1.1.0,>=0.29.1 (from stable_baselines3)
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.5.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.8.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium<1.1.0,>=0.29.1->stable_baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.13->stable_baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (3.0.2)
# Downloading stable_baselines3-2.4.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 14.2 MB/s eta 0:00:00
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 33.9 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium, stable_baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-1.0.0 stable_baselines3-2.4.0
# Collecting ortools
#   Downloading ortools-9.11.4210-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting absl-py>=2.0.0 (from ortools)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from ortools) (1.26.4)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ortools) (2.2.2)
# Collecting protobuf<5.27,>=5.26.1 (from ortools)
#   Downloading protobuf-5.26.1-cp37-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: immutabledict>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from ortools) (4.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->ortools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->ortools) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->ortools) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.17.0)
# Downloading ortools-9.11.4210-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.1/28.1 MB 17.7 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 7.8 MB/s eta 0:00:00
# Downloading protobuf-5.26.1-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.8/302.8 kB 22.3 MB/s eta 0:00:00
# Installing collected packages: protobuf, absl-py, ortools
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.26.1 which is incompatible.
# tensorflow-metadata 1.13.1 requires absl-py<2.0.0,>=0.9, but you have absl-py 2.1.0 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.26.1 which is incompatible.
# Successfully installed absl-py-2.1.0 ortools-9.11.4210 protobuf-5.26.1
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from shimmy) (1.26.4)
# Requirement already satisfied: gymnasium>=1.0.0a1 in /usr/local/lib/python3.10/dist-packages (from shimmy) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=1.0.0a1->shimmy) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=1.0.0a1->shimmy) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=1.0.0a1->shimmy) (0.0.4)
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Installing collected packages: shimmy
# Successfully installed shimmy-2.0.0

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from collections import deque
import random
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd
from stable_baselines3 import PPO, DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from ortools.constraint_solver import pywrapcp, routing_enums_pb2
import gym
from gym import spaces

# %% [markdown]
# Parsing script for Solomon data and enviornment

# %%
def parse_solomon_dataset(file_path):
    """
    Parse Solomon VRPTW C101 dataset
    Returns: Dictionary with problem instance data
    """
    with open(file_path, 'r') as f:
        lines = f.readlines()

    # Parse header information
    vehicle_capacity = int(lines[4].strip().split()[1])

    # Parse customer data (including depot as first customer)
    customers = []
    for line in lines[9:]:  # Data starts at line 9
        if line.strip():
            parts = [float(x) for x in line.strip().split()]
            customer = {
                'id': int(parts[0]),
                'x': parts[1],
                'y': parts[2],
                'demand': parts[3],
                'ready_time': parts[4],
                'due_time': parts[5],
                'service_time': parts[6]
            }
            customers.append(customer)

    return {
        'vehicle_capacity': vehicle_capacity,
        'customers': customers
    }
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Models

# %% [markdown]
# Models and methods

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from collections import deque
import random
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from ortools.constraint_solver import pywrapcp, routing_enums_pb2
import gym
from gym import spaces

# Define VRP Environment
class VRPEnvironment:
    def __init__(self, num_customers=10, grid_size=50, solomon_data=None):
        self.num_customers = num_customers
        self.grid_size = grid_size
        self.travel_time = 0
        self.travel_distance = 0

        if solomon_data:
            # Initialize from Solomon dataset
            self.init_from_solomon(solomon_data)
        else:
            # Random initialization
            self.vehicle_capacity = 200  # Increased for more realistic scenarios
            self.depot = np.array([grid_size/2, grid_size/2])
            self.customers = np.random.randint(0, grid_size, size=(num_customers, 2))
            self.demands = np.random.randint(1, 30, size=num_customers)
            self.ready_times = np.zeros(num_customers)
            self.due_times = np.ones(num_customers) * 1000  # More realistic time windows
            self.service_times = np.ones(num_customers) * 10  # Standard service time

        # Initialize state variables that will be reset
        self.reset()

    def reset(self):
        """Reset the environment to initial state"""
        self.visited = np.zeros(self.num_customers, dtype=bool)
        self.current_pos = self.depot.copy()
        self.current_time = 0
        self.current_load = 0
        self.travel_time = 0
        self.travel_distance = 0
        return self.get_state()

    def init_from_solomon(self, solomon_data):
        """Initialize environment from Solomon dataset with proper scaling"""
        customers = solomon_data['customers']
        self.num_customers = len(customers) - 1  # Exclude depot
        self.vehicle_capacity = solomon_data['vehicle_capacity']

        # Set depot (first customer in Solomon format)
        depot = customers[0]
        self.depot = np.array([depot['x'], depot['y']])

        # Initialize arrays for customers (excluding depot)
        self.customers = np.array([[c['x'], c['y']] for c in customers[1:]])
        self.demands = np.array([c['demand'] for c in customers[1:]])
        self.ready_times = np.array([c['ready_time'] for c in customers[1:]])
        self.due_times = np.array([c['due_time'] for c in customers[1:]])
        self.service_times = np.array([c['service_time'] for c in customers[1:]])


    def get_state(self):
        """Return current state with proper normalization"""
        # Normalize coordinates
        max_coord = max(np.max(self.customers), np.max(self.depot))
        normalized_pos = self.current_pos / max_coord
        normalized_customers = self.customers / max_coord

        # Normalize time windows
        max_time = max(np.max(self.due_times), self.current_time)
        normalized_time = self.current_time / max_time if max_time > 0 else 0

        # Normalize capacity
        normalized_load = self.current_load / self.vehicle_capacity if self.vehicle_capacity > 0 else 0

        return np.concatenate([
            normalized_pos,                    # Current position (2,)
            normalized_customers.flatten(),    # Customer coordinates (num_customers * 2,)
            self.visited.astype(float),       # Visit status (num_customers,)
            [normalized_time],                # Current time (1,)
            [normalized_load],                # Current load (1,)
            self.demands / np.max(self.demands) if np.max(self.demands) > 0 else self.demands,  # Normalized demands
            self.ready_times / max_time if max_time > 0 else self.ready_times,  # Normalized ready times
            self.due_times / max_time if max_time > 0 else self.due_times      # Normalized due times
        ])

    def step(self, action):
        # Check if action is valid
        if action >= self.num_customers:
            return self.get_state(), -100, True

        # Calculate distance to next customer
        next_pos = self.customers[action]
        print("Action:",action)

        print("Current Pos:",self.current_pos)
        print("Next Post", next_pos)
        print(" prev travel dist", self.travel_distance)
        self.travel_distance += np.abs(self.current_pos - next_pos).sum() #manhattan distance for grid
        print("post travel dist", self.travel_distance)
        done = np.all(self.visited)  # Ensure done is defined here

        #print(f"Action mask = {self.action_mask}")
        print(f"Visited = {self.visited}")
        print(f"# cust= {self.num_customers}")

        print(f"Done  = {done}")

        # Update state
        self.current_pos = next_pos
        if self.visited[action]: # already visited - exit
            return self.get_state(), -100, done
        self.visited[action] = True
        num_visited = np.sum(self.visited)

        # Calculate reward components
        progress_reward = 100  # Reward for visiting a new customer

        distance_penalty = -self.travel_distance
        completion_bonus = 1000 if done else 0
        total_reward = distance_penalty + completion_bonus

        print("Total reward", total_reward)

        return self.get_state(), total_reward, done


class GymVRPEnvironment(gym.Env):
    def __init__(self, num_customers=10, grid_size=50, solomon_data=None):
        super(GymVRPEnvironment, self).__init__()
        self.env = VRPEnvironment(num_customers, grid_size, solomon_data)

        # Dynamic state space based on problem size
        state_size = (2 +                     # Current position
                     self.env.num_customers * 2 +  # Customer coordinates
                     self.env.num_customers +      # Visit status
                     1 +                          # Current time
                     1 +                          # Current load
                     self.env.num_customers * 3)  # Demands and time windows

        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(state_size,),
            dtype=np.float32
        )

        self.action_space = spaces.Discrete(self.env.num_customers)

    def reset(self):
        return self.env.reset().astype(np.float32)

    def step(self, action):
        next_state, reward, done = self.env.step(action)
        return next_state.astype(np.float32), reward, done, {}

# Define RL and OR Methods
# OR-Tools Solver
class ORToolsSolver:
    def solve(self, env):
        state = env.reset()
        depot = 0
        num_customers = env.num_customers

        # Create distance matrix
        distance_matrix = np.zeros((num_customers + 1, num_customers + 1))
        all_points = np.vstack([env.depot, env.customers])
        for i in range(num_customers + 1):
            for j in range(num_customers + 1):
                distance_matrix[i][j] = np.abs(all_points[i] - all_points[j]).sum()

        # Set up routing
        manager = pywrapcp.RoutingIndexManager(num_customers + 1, 1, depot)
        routing = pywrapcp.RoutingModel(manager)

        def distance_callback(from_index, to_index):
            from_node = manager.IndexToNode(from_index)
            to_node = manager.IndexToNode(to_index)
            return int(distance_matrix[from_node][to_node])

        transit_callback_index = routing.RegisterTransitCallback(distance_callback)
        routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

        # Solve
        search_parameters = pywrapcp.DefaultRoutingSearchParameters()
        search_parameters.first_solution_strategy = (
            routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

        solution = routing.SolveWithParameters(search_parameters)
        route = []

        if solution:
            index = routing.Start(0)
            while not routing.IsEnd(index):
                route.append(manager.IndexToNode(index) - 1)  # Adjust for depot
                index = solution.Value(routing.NextVar(index))
            route = [node for node in route if node >= 0]  # Remove depot if included

        return route  # Return the visiting order


# PPO Agent
class PPOAgent:
    def __init__(self, env, policy='MlpPolicy', **kwargs):
        self.env = DummyVecEnv([lambda: env])
        self.model = PPO(policy, self.env, **kwargs)

    def train(self, timesteps):
        self.model.learn(total_timesteps=timesteps)

    def evaluate(self, episodes=10):
        rewards = []
        for _ in range(episodes):
            state = self.env.reset()
            episode_reward = 0
            done = False

            while not done:
                action, _ = self.model.predict(state)
                state, reward, done, _ = self.env.step(action)
                episode_reward += reward[0]

            rewards.append(episode_reward)

        return rewards

    def select_action(self, state):
        """Modified to handle numpy array actions"""
        action, _ = self.model.predict(state)
        return int(action[0]) if isinstance(action, np.ndarray) else int(action)

# Baseline DQN Implementation
class DQNNetwork(nn.Module):
    def __init__(self, state_dim, action_dim, hidden_dim=256):  # Increased hidden dim
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),  # Added another layer
            nn.ReLU(),
            nn.Linear(hidden_dim, action_dim)
        )

    def forward(self, x):
        return self.net(x)

class DQNAgent:
    def __init__(self, state_dim, action_dim, hidden_dim=64, lr=1e-3, gamma=0.95):
        self.device = torch.device("cpu")
        self.gamma = gamma
        self.action_dim = action_dim

        self.network = DQNNetwork(state_dim, action_dim, hidden_dim).to(self.device)
        self.target_network = DQNNetwork(state_dim, action_dim, hidden_dim).to(self.device)
        self.target_network.load_state_dict(self.network.state_dict())

        self.optimizer = optim.Adam(self.network.parameters(), lr=lr)
        self.memory = deque(maxlen=10000)
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995

    def select_action(self, state):
        if random.random() < self.epsilon:
            return random.randrange(self.action_dim)

        with torch.no_grad():
            state = torch.FloatTensor(state).to(self.device)
            q_values = self.network(state)
            return q_values.argmax().item()

    def store_transition(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def update(self, batch_size=32):
        if len(self.memory) < batch_size:
            return

        batch = random.sample(self.memory, batch_size)
        state_batch = torch.FloatTensor([t[0] for t in batch]).to(self.device)
        action_batch = torch.LongTensor([t[1] for t in batch]).to(self.device)
        reward_batch = torch.FloatTensor([t[2] for t in batch]).to(self.device)
        next_state_batch = torch.FloatTensor([t[3] for t in batch]).to(self.device)
        done_batch = torch.FloatTensor([t[4] for t in batch]).to(self.device)

        current_q = self.network(state_batch).gather(1, action_batch.unsqueeze(1))
        next_q = self.target_network(next_state_batch).max(1)[0].detach()
        target_q = reward_batch + (1 - done_batch) * self.gamma * next_q

        loss = F.mse_loss(current_q.squeeze(), target_q)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

        return loss.item()

class MaxEntNetwork(nn.Module):
    def __init__(self, state_dim, action_dim, hidden_dim=256):
        super().__init__()

        self.policy_net = nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, action_dim)
        )

        self.value_net = nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1)
        )
        self.action_dim = action_dim


    def policy(self, state):
        logits = self.policy_net(state)
        dist = F.softmax(logits, dim=-1)
        log_prob = F.log_softmax(logits, dim=-1)
        entropy = -(dist * log_prob).sum(dim=-1)
        return dist, entropy

    def value(self, state):
        return self.value_net(state)

class MaxEntRL:
    def __init__(self, state_dim, action_dim, hidden_dim=64, lr=1e-3, gamma=0.95, tau=0.1, alpha=0.1):
        self.gamma = gamma
        self.tau = tau
        self.alpha = alpha
        self.action_dim = action_dim

        # Force CPU usage
        self.device = torch.device("cpu")

        self.network = MaxEntNetwork(state_dim, action_dim, hidden_dim).to(self.device)
        self.target_network = MaxEntNetwork(state_dim, action_dim, hidden_dim).to(self.device)
        self.target_network.load_state_dict(self.network.state_dict())

        self.optimizer = optim.Adam(self.network.parameters(), lr=lr)

        self.memory = deque(maxlen=10000)  # Smaller memory

    def select_action(self, state):
        with torch.no_grad():
            state = torch.FloatTensor(state).to(self.device)
            dist, _ = self.network.policy(state)
            # Mask invalid actions
            #mask = state[-self.action_dim:].bool()
            # Mask indice was fixed - once visited it will be set to false
            mask = ~state[self.action_dim*2+2:self.action_dim*3+2].bool()

            dist = dist * mask
            dist = dist / (dist.sum() + 1e-10)  # Renormalize
            if dist.sum() == 0: # if all the customers are visited and mask is all false
                dist[0] = 1 # send to depot
            action = torch.multinomial(dist, 1).item()
        return action
    def store_transition(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def update(self, batch_size=32):  # Smaller batch size
        if len(self.memory) < batch_size:
            return

        batch = random.sample(self.memory, batch_size)
        state_batch = torch.FloatTensor([t[0] for t in batch]).to(self.device)
        action_batch = torch.LongTensor([t[1] for t in batch]).to(self.device)
        reward_batch = torch.FloatTensor([t[2] for t in batch]).to(self.device)
        next_state_batch = torch.FloatTensor([t[3] for t in batch]).to(self.device)
        done_batch = torch.FloatTensor([t[4] for t in batch]).to(self.device)

        with torch.no_grad():
            next_value = self.target_network.value(next_state_batch).squeeze()
            expected_value = reward_batch + self.gamma * next_value * (1 - done_batch)

        curr_value = self.network.value(state_batch).squeeze()
        value_loss = F.mse_loss(curr_value, expected_value)

        dist, entropy = self.network.policy(state_batch)
        log_prob = torch.log(dist + 1e-10)
        advantage = (expected_value - curr_value).detach()

        policy_loss = -(log_prob[range(batch_size), action_batch] * advantage).mean()
        entropy_loss = -entropy.mean()

        total_loss = value_loss + policy_loss + self.alpha * entropy_loss

        self.optimizer.zero_grad()
        total_loss.backward()
        self.optimizer.step()

        # Soft update target network
        for target_param, param in zip(self.target_network.parameters(), self.network.parameters()):
            target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

        return total_loss.item()

# SAC Implementation (simplified version)
class SACNetwork(nn.Module):
    def __init__(self, state_dim, action_dim, hidden_dim=256):
        super().__init__()

        # Actor network outputs mean and log_std for each action
        self.actor = nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, action_dim * 2)  # Mean and log_std for each action
        )

        # Two Q-networks for double Q-learning
        self.q1 = nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, action_dim)  # Q-value for each action
        )

        self.q2 = nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, action_dim)  # Q-value for each action
        )

        # Target Q-networks
        self.target_q1 = nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, action_dim)
        )

        self.target_q2 = nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, action_dim)
        )

class SACAgent:
    def __init__(self, state_dim, action_dim, hidden_dim=256, lr=3e-4, gamma=0.99, tau=0.005, alpha=0.2, buffer_size=100000):
        self.device = torch.device("cpu")
        self.gamma = gamma
        self.tau = tau
        self.alpha = alpha
        self.action_dim = action_dim

        self.network = SACNetwork(state_dim, action_dim, hidden_dim).to(self.device)

        # Separate optimizers for actor and critics
        self.actor_optimizer = optim.Adam(self.network.actor.parameters(), lr=lr)
        self.q1_optimizer = optim.Adam(self.network.q1.parameters(), lr=lr)
        self.q2_optimizer = optim.Adam(self.network.q2.parameters(), lr=lr)

        # Initialize target networks
        for target_param, param in zip(self.network.target_q1.parameters(), self.network.q1.parameters()):
            target_param.data.copy_(param.data)
        for target_param, param in zip(self.network.target_q2.parameters(), self.network.q2.parameters()):
            target_param.data.copy_(param.data)

        self.memory = deque(maxlen=buffer_size)

        # Temperature parameter
        self.target_entropy = -action_dim  # Target entropy is -|A|
        self.log_alpha = torch.zeros(1, requires_grad=True, device=self.device)
        self.alpha_optimizer = optim.Adam([self.log_alpha], lr=lr)

    def select_action(self, state):
        with torch.no_grad():
            state = torch.FloatTensor(state).to(self.device)
            output = self.network.actor(state)
            mean, log_std = output.chunk(2, dim=-1)
            log_std = torch.clamp(log_std, -20, 2)
            std = log_std.exp()

            # Use reparameterization trick
            normal = torch.distributions.Normal(mean, std)
            action = normal.rsample()

            # Apply softmax and mask
            action_probs = F.softmax(action, dim=-1)
            #mask = state[-self.action_dim:].bool()
            # Mask indice was fixed - once visited it will be set to false
            mask = ~state[self.action_dim*2+2:self.action_dim*3+2].bool()

            action_probs = action_probs * mask
            action_probs = action_probs / (action_probs.sum() + 1e-10)
            return action_probs.argmax().item()

    def store_transition(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def update(self, batch_size=256):
        if len(self.memory) < batch_size:
            return

        # Sample batch
        batch = random.sample(self.memory, batch_size)
        state_batch = torch.FloatTensor([t[0] for t in batch]).to(self.device)
        action_batch = torch.LongTensor([t[1] for t in batch]).to(self.device)
        reward_batch = torch.FloatTensor([t[2] for t in batch]).to(self.device)
        next_state_batch = torch.FloatTensor([t[3] for t in batch]).to(self.device)
        done_batch = torch.FloatTensor([t[4] for t in batch]).to(self.device)

        # Update temperature parameter
        actor_output = self.network.actor(state_batch)
        mean, log_std = actor_output.chunk(2, dim=-1)
        log_std = torch.clamp(log_std, -20, 2)
        std = log_std.exp()
        normal = torch.distributions.Normal(mean, std)
        sampled_actions = normal.rsample()
        log_probs = normal.log_prob(sampled_actions).sum(dim=-1)

        alpha_loss = -(self.log_alpha * (log_probs + self.target_entropy).detach()).mean()
        self.alpha_optimizer.zero_grad()
        alpha_loss.backward()
        self.alpha_optimizer.step()

        self.alpha = self.log_alpha.exp().item()

        # Update critics
        with torch.no_grad():
            next_actor_output = self.network.actor(next_state_batch)
            next_mean, next_log_std = next_actor_output.chunk(2, dim=-1)
            next_log_std = torch.clamp(next_log_std, -20, 2)
            next_std = next_log_std.exp()
            next_normal = torch.distributions.Normal(next_mean, next_std)
            next_actions = next_normal.rsample()
            next_log_probs = next_normal.log_prob(next_actions).sum(dim=-1)

            next_action_probs = F.softmax(next_actions, dim=-1)
            next_q1 = self.network.target_q1(next_state_batch)
            next_q2 = self.network.target_q2(next_state_batch)
            next_q = torch.min(next_q1, next_q2)
            next_q = (next_action_probs * next_q).sum(dim=1)
            target_q = reward_batch + (1 - done_batch) * self.gamma * (next_q - self.alpha * next_log_probs)

        # Get current Q estimates
        current_q1 = self.network.q1(state_batch)
        current_q2 = self.network.q2(state_batch)
        current_q1 = current_q1.gather(1, action_batch.unsqueeze(1)).squeeze()
        current_q2 = current_q2.gather(1, action_batch.unsqueeze(1)).squeeze()

        # Compute critic losses
        q1_loss = F.mse_loss(current_q1, target_q)
        q2_loss = F.mse_loss(current_q2, target_q)

        # Update critics
        self.q1_optimizer.zero_grad()
        q1_loss.backward()
        self.q1_optimizer.step()

        self.q2_optimizer.zero_grad()
        q2_loss.backward()
        self.q2_optimizer.step()

        # Update actor
        actor_output = self.network.actor(state_batch)
        mean, log_std = actor_output.chunk(2, dim=-1)
        log_std = torch.clamp(log_std, -20, 2)
        std = log_std.exp()
        normal = torch.distributions.Normal(mean, std)
        actions = normal.rsample()
        log_probs = normal.log_prob(actions).sum(dim=-1)

        action_probs = F.softmax(actions, dim=-1)
        q1 = self.network.q1(state_batch)
        q2 = self.network.q2(state_batch)
        q = torch.min(q1, q2)
        q = (action_probs * q).sum(dim=1)

        actor_loss = (self.alpha * log_probs - q).mean()

        # Update actor
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        # Soft update target networks
        for target_param, param in zip(self.network.target_q1.parameters(), self.network.q1.parameters()):
            target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)
        for target_param, param in zip(self.network.target_q2.parameters(), self.network.q2.parameters()):
            target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

        return actor_loss.item()

class NearestNeighbor:
    def solve(self, env):
        state = env.reset()
        current_pos = env.depot.copy()
        unvisited = set(range(env.num_customers))
        route = []  # To track the visiting order
        total_distance = 0

        while unvisited:
            nearest =  min(unvisited, key=lambda i: np.abs(current_pos - env.customers[i]).sum())
            total_distance += np.abs(current_pos - env.customers[nearest]).sum()
            route.append(nearest)
            current_pos = env.customers[nearest]
            unvisited.remove(nearest)

        total_distance += np.abs(current_pos - env.depot).sum()
        route.append(0)  # Return to depot
        return route  # Return the visiting order

# %%
def calculate_route_distance(env, route):
    """
    Calculate the total route distance:
    1. Start from depot
    2. Visit each customer in route order
    3. Return to depot
    """
    if not route or len(set(route)) < env.num_customers:  # Check if route is complete
        return float('inf')  # Invalid/incomplete route

    total_distance = 0
    current_pos = env.depot.copy()

    # Follow route customer by customer
    for customer_idx in route:
        if customer_idx >= env.num_customers:  # Invalid customer index
            return float('inf')

        # Distance to next customer
        customer_pos = env.customers[customer_idx]
        distance = np.abs(current_pos - customer_pos).sum()
        total_distance += distance
        current_pos = customer_pos.copy()

    # Return to depot
    total_distance += np.abs(current_pos - env.depot).sum()

    return total_distance

def validate_route(env, route):
    """
    Validate if route is complete and feasible:
    1. All customers visited exactly once
    2. Valid customer indices
    3. Capacity constraints respected
    4. Time windows respected
    """
    env = env.env
    if not route:
        return False, "Empty route"

    # Check if all customers are visited exactly once
    visited = set(route)
    if len(visited) != env.num_customers:
        return False, f"Not all customers visited. Visited {len(visited)}/{env.num_customers}"

    # Check valid indices
    if any(i >= env.num_customers for i in route):
        return False, "Invalid customer index"

    # Check capacity constraints
    total_load = 0
    for customer_idx in route:
        total_load += env.demands[customer_idx]
        if total_load > env.vehicle_capacity:
            return False, "Capacity constraint violated"

    # Check time windows
    current_time = 0
    current_pos = env.depot.copy()

    for customer_idx in route:
        customer_pos = env.customers[customer_idx]
        travel_time = np.abs(current_pos - customer_pos).sum()

        arrival_time = current_time + travel_time
        if arrival_time > env.due_times[customer_idx]:
            return False, "Time window violated - arrived too late"

        service_start = max(arrival_time, env.ready_times[customer_idx])
        current_time = service_start + env.service_times[customer_idx]
        current_pos = customer_pos.copy()

    # Check return to depot
    final_time = current_time + np.abs(current_pos - env.depot).sum()
    if final_time > max(env.due_times):
        return False, "Cannot return to depot within time window"

    return True, "Valid route"

class RouteTracker:
    def __init__(self):
        self.episode_routes = []
        self.episode_distances = []
        self.episode_rewards = []
        self.best_route = None
        self.best_distance = float('inf')

    def add_episode(self, env, route, reward):

        # Calculate distance
        distance = calculate_route_distance(env.env, route)
        valid, msg = validate_route(env, route)
        print(f"adding episode =  {route}, valid = {valid}, reward = {reward}")
        if valid and distance < self.best_distance:
            self.best_distance = distance
            self.best_route = route.copy()
            print(f"New best route found! Distance: {distance:.2f}")
            print(f"Route: {route}")

        self.episode_routes.append(route)
        self.episode_distances.append(distance)
        self.episode_rewards.append(reward)

    def get_statistics(self):
        valid_distances = [d for d in self.episode_distances if d != float('inf')]
        avg_distance = np.mean(valid_distances) if valid_distances else float('inf')

        return {
            'avg_distance': avg_distance,
            'best_distance': self.best_distance,
            'best_route': self.best_route,
            'avg_reward': np.mean(self.episode_rewards),
            'completion_rate': len(valid_distances) / len(self.episode_distances),
            'all_distances': self.episode_distances,
            'all_rewards': self.episode_rewards
        }

def print_route_details(env, route):
    """Print detailed information about a route"""
    if not route:
        print("Empty route!")
        return

    print("\nRoute Details:")
    print(f"Number of customers visited: {len(set(route))}/{env.num_customers}")

    total_distance = 0
    current_time = 0
    current_pos = env.depot.copy()
    total_load = 0

    print("\nStep-by-step route:")
    print(f"Start at depot: {env.depot}")

    for i, customer_idx in enumerate(route, 1):
        customer_pos = env.customers[customer_idx]
        distance = np.abs(current_pos - customer_pos).sum()
        total_distance += distance

        arrival_time = current_time + distance
        service_start = max(arrival_time, env.ready_times[customer_idx])
        total_load += env.demands[customer_idx]

        print(f"\nStep {i}:")
        print(f"Visit customer {customer_idx} at position {customer_pos}")
        print(f"Travel distance: {distance:.2f}")
        print(f"Arrival time: {arrival_time:.2f}")
        print(f"Service start: {service_start:.2f}")
        print(f"Due time: {env.due_times[customer_idx]:.2f}")
        print(f"Current load: {total_load}/{env.vehicle_capacity}")

        current_time = service_start + env.service_times[customer_idx]
        current_pos = customer_pos.copy()

    # Return to depot
    final_distance = np.abs(current_pos - env.depot).sum()
    total_distance += final_distance
    final_time = current_time + final_distance

    print("\nReturn to depot:")
    print(f"Final leg distance: {final_distance:.2f}")
    print(f"Final arrival time: {final_time:.2f}")
    print(f"\nTotal route distance: {total_distance:.2f}")
    print(f"Total time: {final_time:.2f}")
    print(f"Total load: {total_load}/{env.vehicle_capacity}")

# %%
def train_agent(env, agent, num_episodes=10):
    tracker = RouteTracker()

    for episode in range(num_episodes):
        state = env.reset()
        current_route = []
        episode_reward = 0
        done = False

        while not done:
            action = agent.select_action(state)
            next_state, reward, done, _ = env.step(action)
            # Store transition for learning
            agent.store_transition(state, action, reward, next_state, done)
            agent.update()

            # Track route
            current_route.append(action)
            episode_reward += reward
            state = next_state

        # Add episode to tracker
        tracker.add_episode(env, current_route, episode_reward)

        # Print progress every 100 episodes
        if (episode + 1) % 100 == 0:
            stats = tracker.get_statistics()
            print(f"\nEpisode {episode + 1}")
            print(f"Average Distance: {stats['avg_distance']:.2f}")
            print(f"Best Distance: {stats['best_distance']:.2f}")
            print(f"Average Reward: {stats['avg_reward']:.2f}")
            print(f"Completion Rate: {stats['completion_rate']*100:.1f}%")

    return tracker

# Usage example:
env = GymVRPEnvironment(num_customers=10)
#agent = DQNAgent(state_dim=env.observation_space.shape[0],action_dim=env.action_space.n,hidden_dim=256)
agent = SACAgent(state_dim=env.observation_space.shape[0],
                 action_dim=env.action_space.n,
                 hidden_dim=256)

# Train agent
tracker = train_agent(env, agent)

# Print final statistics
stats = tracker.get_statistics()
print("\nFinal Statistics:")
print(f"Best Distance Found: {stats['best_distance']:.2f}")
print(f"Average Distance: {stats['avg_distance']:.2f}")
print(f"Completion Rate: {stats['completion_rate']*100:.1f}%")

# Print detailed analysis of best route
if tracker.best_route is not None:
    print("\nBest Route Details:")
    print_route_details(env.env, tracker.best_route)
# Out:
# Action: 5
# Current Pos: [25. 25.]
# Next Post [18 34]
#  prev travel dist 0
# post travel dist 16.0
# Visited = [False False False False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -16.0
# Action: 0
# Current Pos: [18 34]
# Next Post [27  8]
#  prev travel dist 16.0
# post travel dist 51.0
# Visited = [False False False False False  True False False False False]
# # cust= 10
# Done  = False
# Total reward -51.0
# Action: 7
# Current Pos: [27  8]
# Next Post [25 43]
#  prev travel dist 51.0
# post travel dist 88.0
# Visited = [ True False False False False  True False False False False]
# # cust= 10
# Done  = False
# Total reward -88.0
# Action: 6
# Current Pos: [25 43]
# Next Post [14 45]
#  prev travel dist 88.0
# post travel dist 101.0
# Visited = [ True False False False False  True False  True False False]
# # cust= 10
# Done  = False
# Total reward -101.0
# Action: 8
# Current Pos: [14 45]
# Next Post [23 22]
#  prev travel dist 101.0
# post travel dist 133.0
# Visited = [ True False False False False  True  True  True False False]
# # cust= 10
# Done  = False
# Total reward -133.0
# Action: 9
# Current Pos: [23 22]
# Next Post [40 33]
#  prev travel dist 133.0
# post travel dist 161.0
# Visited = [ True False False False False  True  True  True  True False]
# # cust= 10
# Done  = False
# Total reward -161.0
# Action: 2
# Current Pos: [40 33]
# Next Post [42 49]
#  prev travel dist 161.0
# post travel dist 179.0
# Visited = [ True False False False False  True  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -179.0
# Action: 1
# Current Pos: [42 49]
# Next Post [10 40]
#  prev travel dist 179.0
# post travel dist 220.0
# Visited = [ True False  True False False  True  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -220.0
# Action: 3
# Current Pos: [10 40]
# Next Post [45 38]
#  prev travel dist 220.0
# post travel dist 257.0
# Visited = [ True  True  True False False  True  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -257.0
# Action: 4
# Current Pos: [45 38]
# Next Post [48 49]
#  prev travel dist 257.0
# post travel dist 271.0
# Visited = [ True  True  True  True False  True  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -271.0
# Action: 0
# Current Pos: [48 49]
# Next Post [27  8]
#  prev travel dist 271.0
# post travel dist 333.0
# Visited = [ True  True  True  True  True  True  True  True  True  True]
# # cust= 10
# Done  = True
# adding episode =  [5, 0, 7, 6, 8, 9, 2, 1, 3, 4, 0], valid = True, reward = -1577.0
# New best route found! Distance: 352.00
# Route: [5, 0, 7, 6, 8, 9, 2, 1, 3, 4, 0]
# Action: 8
# Current Pos: [25. 25.]
# Next Post [23 22]
#  prev travel dist 0
# post travel dist 5.0
# Visited = [False False False False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -5.0
# Action: 6
# Current Pos: [23 22]
# Next Post [14 45]
#  prev travel dist 5.0
# post travel dist 37.0
# Visited = [False False False False False False False False  True False]
# # cust= 10
# Done  = False
# Total reward -37.0
# Action: 3
# Current Pos: [14 45]
# Next Post [45 38]
#  prev travel dist 37.0
# post travel dist 75.0
# Visited = [False False False False False False  True False  True False]
# # cust= 10
# Done  = False
# Total reward -75.0
# Action: 7
# Current Pos: [45 38]
# Next Post [25 43]
#  prev travel dist 75.0
# post travel dist 100.0
# Visited = [False False False  True False False  True False  True False]
# # cust= 10
# Done  = False
# Total reward -100.0
# Action: 4
# Current Pos: [25 43]
# Next Post [48 49]
#  prev travel dist 100.0
# post travel dist 129.0
# Visited = [False False False  True False False  True  True  True False]
# # cust= 10
# Done  = False
# Total reward -129.0
# Action: 2
# Current Pos: [48 49]
# Next Post [42 49]
#  prev travel dist 129.0
# post travel dist 135.0
# Visited = [False False False  True  True False  True  True  True False]
# # cust= 10
# Done  = False
# Total reward -135.0
# Action: 5
# Current Pos: [42 49]
# Next Post [18 34]
#  prev travel dist 135.0
# post travel dist 174.0
# Visited = [False False  True  True  True False  True  True  True False]
# # cust= 10
# Done  = False
# Total reward -174.0
# Action: 1
# Current Pos: [18 34]
# Next Post [10 40]
#  prev travel dist 174.0
# post travel dist 188.0
# Visited = [False False  True  True  True  True  True  True  True False]
# # cust= 10
# Done  = False
# Total reward -188.0
# Action: 0
# Current Pos: [10 40]
# Next Post [27  8]
#  prev travel dist 188.0
# post travel dist 237.0
# Visited = [False  True  True  True  True  True  True  True  True False]
# # cust= 10
# Done  = False
# Total reward -237.0
# Action: 9
# Current Pos: [27  8]
# Next Post [40 33]
#  prev travel dist 237.0
# post travel dist 275.0
# Visited = [ True  True  True  True  True  True  True  True  True False]
# # cust= 10
# Done  = False
# Total reward -275.0
# Action: 0
# Current Pos: [40 33]
# Next Post [27  8]
#  prev travel dist 275.0
# post travel dist 313.0
# Visited = [ True  True  True  True  True  True  True  True  True  True]
# # cust= 10
# Done  = True
# adding episode =  [8, 6, 3, 7, 4, 2, 5, 1, 0, 9, 0], valid = True, reward = -1455.0
# New best route found! Distance: 332.00
# Route: [8, 6, 3, 7, 4, 2, 5, 1, 0, 9, 0]
# Action: 0
# Current Pos: [25. 25.]
# Next Post [27  8]
#  prev travel dist 0
# post travel dist 19.0
# Visited = [False False False False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -19.0
# Action: 6
# Current Pos: [27  8]
# Next Post [14 45]
#  prev travel dist 19.0
# post travel dist 69.0
# Visited = [ True False False False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -69.0
# Action: 7
# Current Pos: [14 45]
# Next Post [25 43]
#  prev travel dist 69.0
# post travel dist 82.0
# Visited = [ True False False False False False  True False False False]
# # cust= 10
# Done  = False
# Total reward -82.0
# Action: 1
# Current Pos: [25 43]
# Next Post [10 40]
#  prev travel dist 82.0
# post travel dist 100.0
# Visited = [ True False False False False False  True  True False False]
# # cust= 10
# Done  = False
# Total reward -100.0
# Action: 9
# Current Pos: [10 40]
# Next Post [40 33]
#  prev travel dist 100.0
# post travel dist 137.0
# Visited = [ True  True False False False False  True  True False False]
# # cust= 10
# Done  = False
# Total reward -137.0
# Action: 4
# Current Pos: [40 33]
# Next Post [48 49]
#  prev travel dist 137.0
# post travel dist 161.0
# Visited = [ True  True False False False False  True  True False  True]
# # cust= 10
# Done  = False
# Total reward -161.0
# Action: 5
# Current Pos: [48 49]
# Next Post [18 34]
#  prev travel dist 161.0
# post travel dist 206.0
# Visited = [ True  True False False  True False  True  True False  True]
# # cust= 10
# Done  = False
# Total reward -206.0
# Action: 3
# Current Pos: [18 34]
# Next Post [45 38]
#  prev travel dist 206.0
# post travel dist 237.0
# Visited = [ True  True False False  True  True  True  True False  True]
# # cust= 10
# Done  = False
# Total reward -237.0
# Action: 8
# Current Pos: [45 38]
# Next Post [23 22]
#  prev travel dist 237.0
# post travel dist 275.0
# Visited = [ True  True False  True  True  True  True  True False  True]
# # cust= 10
# Done  = False
# Total reward -275.0
# Action: 2
# Current Pos: [23 22]
# Next Post [42 49]
#  prev travel dist 275.0
# post travel dist 321.0
# Visited = [ True  True False  True  True  True  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -321.0
# Action: 0
# Current Pos: [42 49]
# Next Post [27  8]
#  prev travel dist 321.0
# post travel dist 377.0
# Visited = [ True  True  True  True  True  True  True  True  True  True]
# # cust= 10
# Done  = True
# adding episode =  [0, 6, 7, 1, 9, 4, 5, 3, 8, 2, 0], valid = True, reward = -1707.0
# Action: 0
# Current Pos: [25. 25.]
# Next Post [27  8]
#  prev travel dist 0
# post travel dist 19.0
# Visited = [False False False False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -19.0
# Action: 8
# Current Pos: [27  8]
# Next Post [23 22]
#  prev travel dist 19.0
# post travel dist 37.0
# Visited = [ True False False False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -37.0
# Action: 7
# Current Pos: [23 22]
# Next Post [25 43]
#  prev travel dist 37.0
# post travel dist 60.0
# Visited = [ True False False False False False False False  True False]
# # cust= 10
# Done  = False
# Total reward -60.0
# Action: 9
# Current Pos: [25 43]
# Next Post [40 33]
#  prev travel dist 60.0
# post travel dist 85.0
# Visited = [ True False False False False False False  True  True False]
# # cust= 10
# Done  = False
# Total reward -85.0
# Action: 6
# Current Pos: [40 33]
# Next Post [14 45]
#  prev travel dist 85.0
# post travel dist 123.0
# Visited = [ True False False False False False False  True  True  True]
# # cust= 10
# Done  = False
# Total reward -123.0
# Action: 4
# Current Pos: [14 45]
# Next Post [48 49]
#  prev travel dist 123.0
# post travel dist 161.0
# Visited = [ True False False False False False  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -161.0
# Action: 2
# Current Pos: [48 49]
# Next Post [42 49]
#  prev travel dist 161.0
# post travel dist 167.0
# Visited = [ True False False False  True False  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -167.0
# Action: 1
# Current Pos: [42 49]
# Next Post [10 40]
#  prev travel dist 167.0
# post travel dist 208.0
# Visited = [ True False  True False  True False  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -208.0
# Action: 3
# Current Pos: [10 40]
# Next Post [45 38]
#  prev travel dist 208.0
# post travel dist 245.0
# Visited = [ True  True  True False  True False  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -245.0
# Action: 5
# Current Pos: [45 38]
# Next Post [18 34]
#  prev travel dist 245.0
# post travel dist 276.0
# Visited = [ True  True  True  True  True False  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -276.0
# Action: 0
# Current Pos: [18 34]
# Next Post [27  8]
#  prev travel dist 276.0
# post travel dist 311.0
# Visited = [ True  True  True  True  True  True  True  True  True  True]
# # cust= 10
# Done  = True
# adding episode =  [0, 8, 7, 9, 6, 4, 2, 1, 3, 5, 0], valid = True, reward = -1481.0
# New best route found! Distance: 330.00
# Route: [0, 8, 7, 9, 6, 4, 2, 1, 3, 5, 0]
# Action: 0
# Current Pos: [25. 25.]
# Next Post [27  8]
#  prev travel dist 0
# post travel dist 19.0
# Visited = [False False False False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -19.0
# Action: 5
# Current Pos: [27  8]
# Next Post [18 34]
#  prev travel dist 19.0
# post travel dist 54.0
# Visited = [ True False False False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -54.0
# Action: 2
# Current Pos: [18 34]
# Next Post [42 49]
#  prev travel dist 54.0
# post travel dist 93.0
# Visited = [ True False False False False  True False False False False]
# # cust= 10
# Done  = False
# Total reward -93.0
# Action: 6
# Current Pos: [42 49]
# Next Post [14 45]
#  prev travel dist 93.0
# post travel dist 125.0
# Visited = [ True False  True False False  True False False False False]
# # cust= 10
# Done  = False
# Total reward -125.0
# Action: 4
# Current Pos: [14 45]
# Next Post [48 49]
#  prev travel dist 125.0
# post travel dist 163.0
# Visited = [ True False  True False False  True  True False False False]
# # cust= 10
# Done  = False
# Total reward -163.0
# Action: 7
# Current Pos: [48 49]
# Next Post [25 43]
#  prev travel dist 163.0
# post travel dist 192.0
# Visited = [ True False  True False  True  True  True False False False]
# # cust= 10
# Done  = False
# Total reward -192.0
# Action: 3
# Current Pos: [25 43]
# Next Post [45 38]
#  prev travel dist 192.0
# post travel dist 217.0
# Visited = [ True False  True False  True  True  True  True False False]
# # cust= 10
# Done  = False
# Total reward -217.0
# Action: 8
# Current Pos: [45 38]
# Next Post [23 22]
#  prev travel dist 217.0
# post travel dist 255.0
# Visited = [ True False  True  True  True  True  True  True False False]
# # cust= 10
# Done  = False
# Total reward -255.0
# Action: 9
# Current Pos: [23 22]
# Next Post [40 33]
#  prev travel dist 255.0
# post travel dist 283.0
# Visited = [ True False  True  True  True  True  True  True  True False]
# # cust= 10
# Done  = False
# Total reward -283.0
# Action: 1
# Current Pos: [40 33]
# Next Post [10 40]
#  prev travel dist 283.0
# post travel dist 320.0
# Visited = [ True False  True  True  True  True  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -320.0
# Action: 0
# Current Pos: [10 40]
# Next Post [27  8]
#  prev travel dist 320.0
# post travel dist 369.0
# Visited = [ True  True  True  True  True  True  True  True  True  True]
# # cust= 10
# Done  = True
# adding episode =  [0, 5, 2, 6, 4, 7, 3, 8, 9, 1, 0], valid = True, reward = -1821.0
# Action: 2
# Current Pos: [25. 25.]
# Next Post [42 49]
#  prev travel dist 0
# post travel dist 41.0
# Visited = [False False False False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -41.0
# Action: 1
# Current Pos: [42 49]
# Next Post [10 40]
#  prev travel dist 41.0
# post travel dist 82.0
# Visited = [False False  True False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -82.0
# Action: 4
# Current Pos: [10 40]
# Next Post [48 49]
#  prev travel dist 82.0
# post travel dist 129.0
# Visited = [False  True  True False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -129.0
# Action: 0
# Current Pos: [48 49]
# Next Post [27  8]
#  prev travel dist 129.0
# post travel dist 191.0
# Visited = [False  True  True False  True False False False False False]
# # cust= 10
# Done  = False
# Total reward -191.0
# Action: 3
# Current Pos: [27  8]
# Next Post [45 38]
#  prev travel dist 191.0
# post travel dist 239.0
# Visited = [ True  True  True False  True False False False False False]
# # cust= 10
# Done  = False
# Total reward -239.0
# Action: 6
# Current Pos: [45 38]
# Next Post [14 45]
#  prev travel dist 239.0
# post travel dist 277.0
# Visited = [ True  True  True  True  True False False False False False]
# # cust= 10
# Done  = False
# Total reward -277.0
# Action: 5
# Current Pos: [14 45]
# Next Post [18 34]
#  prev travel dist 277.0
# post travel dist 292.0
# Visited = [ True  True  True  True  True False  True False False False]
# # cust= 10
# Done  = False
# Total reward -292.0
# Action: 9
# Current Pos: [18 34]
# Next Post [40 33]
#  prev travel dist 292.0
# post travel dist 315.0
# Visited = [ True  True  True  True  True  True  True False False False]
# # cust= 10
# Done  = False
# Total reward -315.0
# Action: 8
# Current Pos: [40 33]
# Next Post [23 22]
#  prev travel dist 315.0
# post travel dist 343.0
# Visited = [ True  True  True  True  True  True  True False False  True]
# # cust= 10
# Done  = False
# Total reward -343.0
# Action: 7
# Current Pos: [23 22]
# Next Post [25 43]
#  prev travel dist 343.0
# post travel dist 366.0
# Visited = [ True  True  True  True  True  True  True False  True  True]
# # cust= 10
# Done  = False
# Total reward -366.0
# Action: 0
# Current Pos: [25 43]
# Next Post [27  8]
#  prev travel dist 366.0
# post travel dist 403.0
# Visited = [ True  True  True  True  True  True  True  True  True  True]
# # cust= 10
# Done  = True
# adding episode =  [2, 1, 4, 0, 3, 6, 5, 9, 8, 7, 0], valid = True, reward = -2375.0
# Action: 4
# Current Pos: [25. 25.]
# Next Post [48 49]
#  prev travel dist 0
# post travel dist 47.0
# Visited = [False False False False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -47.0
# Action: 2
# Current Pos: [48 49]
# Next Post [42 49]
#  prev travel dist 47.0
# post travel dist 53.0
# Visited = [False False False False  True False False False False False]
# # cust= 10
# Done  = False
# Total reward -53.0
# Action: 0
# Current Pos: [42 49]
# Next Post [27  8]
#  prev travel dist 53.0
# post travel dist 109.0
# Visited = [False False  True False  True False False False False False]
# # cust= 10
# Done  = False
# Total reward -109.0
# Action: 8
# Current Pos: [27  8]
# Next Post [23 22]
#  prev travel dist 109.0
# post travel dist 127.0
# Visited = [ True False  True False  True False False False False False]
# # cust= 10
# Done  = False
# Total reward -127.0
# Action: 3
# Current Pos: [23 22]
# Next Post [45 38]
#  prev travel dist 127.0
# post travel dist 165.0
# Visited = [ True False  True False  True False False False  True False]
# # cust= 10
# Done  = False
# Total reward -165.0
# Action: 9
# Current Pos: [45 38]
# Next Post [40 33]
#  prev travel dist 165.0
# post travel dist 175.0
# Visited = [ True False  True  True  True False False False  True False]
# # cust= 10
# Done  = False
# Total reward -175.0
# Action: 6
# Current Pos: [40 33]
# Next Post [14 45]
#  prev travel dist 175.0
# post travel dist 213.0
# Visited = [ True False  True  True  True False False False  True  True]
# # cust= 10
# Done  = False
# Total reward -213.0
# Action: 7
# Current Pos: [14 45]
# Next Post [25 43]
#  prev travel dist 213.0
# post travel dist 226.0
# Visited = [ True False  True  True  True False  True False  True  True]
# # cust= 10
# Done  = False
# Total reward -226.0
# Action: 1
# Current Pos: [25 43]
# Next Post [10 40]
#  prev travel dist 226.0
# post travel dist 244.0
# Visited = [ True False  True  True  True False  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -244.0
# Action: 5
# Current Pos: [10 40]
# Next Post [18 34]
#  prev travel dist 244.0
# post travel dist 258.0
# Visited = [ True  True  True  True  True False  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -258.0
# Action: 0
# Current Pos: [18 34]
# Next Post [27  8]
#  prev travel dist 258.0
# post travel dist 293.0
# Visited = [ True  True  True  True  True  True  True  True  True  True]
# # cust= 10
# Done  = True
# adding episode =  [4, 2, 0, 8, 3, 9, 6, 7, 1, 5, 0], valid = True, reward = -1717.0
# New best route found! Distance: 312.00
# Route: [4, 2, 0, 8, 3, 9, 6, 7, 1, 5, 0]
# Action: 2
# Current Pos: [25. 25.]
# Next Post [42 49]
#  prev travel dist 0
# post travel dist 41.0
# Visited = [False False False False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -41.0
# Action: 1
# Current Pos: [42 49]
# Next Post [10 40]
#  prev travel dist 41.0
# post travel dist 82.0
# Visited = [False False  True False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -82.0
# Action: 4
# Current Pos: [10 40]
# Next Post [48 49]
#  prev travel dist 82.0
# post travel dist 129.0
# Visited = [False  True  True False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -129.0
# Action: 9
# Current Pos: [48 49]
# Next Post [40 33]
#  prev travel dist 129.0
# post travel dist 153.0
# Visited = [False  True  True False  True False False False False False]
# # cust= 10
# Done  = False
# Total reward -153.0
# Action: 6
# Current Pos: [40 33]
# Next Post [14 45]
#  prev travel dist 153.0
# post travel dist 191.0
# Visited = [False  True  True False  True False False False False  True]
# # cust= 10
# Done  = False
# Total reward -191.0
# Action: 0
# Current Pos: [14 45]
# Next Post [27  8]
#  prev travel dist 191.0
# post travel dist 241.0
# Visited = [False  True  True False  True False  True False False  True]
# # cust= 10
# Done  = False
# Total reward -241.0
# Action: 8
# Current Pos: [27  8]
# Next Post [23 22]
#  prev travel dist 241.0
# post travel dist 259.0
# Visited = [ True  True  True False  True False  True False False  True]
# # cust= 10
# Done  = False
# Total reward -259.0
# Action: 7
# Current Pos: [23 22]
# Next Post [25 43]
#  prev travel dist 259.0
# post travel dist 282.0
# Visited = [ True  True  True False  True False  True False  True  True]
# # cust= 10
# Done  = False
# Total reward -282.0
# Action: 5
# Current Pos: [25 43]
# Next Post [18 34]
#  prev travel dist 282.0
# post travel dist 298.0
# Visited = [ True  True  True False  True False  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -298.0
# Action: 3
# Current Pos: [18 34]
# Next Post [45 38]
#  prev travel dist 298.0
# post travel dist 329.0
# Visited = [ True  True  True False  True  True  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -329.0
# Action: 0
# Current Pos: [45 38]
# Next Post [27  8]
#  prev travel dist 329.0
# post travel dist 377.0
# Visited = [ True  True  True  True  True  True  True  True  True  True]
# # cust= 10
# Done  = True
# adding episode =  [2, 1, 4, 9, 6, 0, 8, 7, 5, 3, 0], valid = True, reward = -2105.0
# Action: 1
# Current Pos: [25. 25.]
# Next Post [10 40]
#  prev travel dist 0
# post travel dist 30.0
# Visited = [False False False False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -30.0
# Action: 8
# Current Pos: [10 40]
# Next Post [23 22]
#  prev travel dist 30.0
# post travel dist 61.0
# Visited = [False  True False False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -61.0
# Action: 9
# Current Pos: [23 22]
# Next Post [40 33]
#  prev travel dist 61.0
# post travel dist 89.0
# Visited = [False  True False False False False False False  True False]
# # cust= 10
# Done  = False
# Total reward -89.0
# Action: 0
# Current Pos: [40 33]
# Next Post [27  8]
#  prev travel dist 89.0
# post travel dist 127.0
# Visited = [False  True False False False False False False  True  True]
# # cust= 10
# Done  = False
# Total reward -127.0
# Action: 5
# Current Pos: [27  8]
# Next Post [18 34]
#  prev travel dist 127.0
# post travel dist 162.0
# Visited = [ True  True False False False False False False  True  True]
# # cust= 10
# Done  = False
# Total reward -162.0
# Action: 3
# Current Pos: [18 34]
# Next Post [45 38]
#  prev travel dist 162.0
# post travel dist 193.0
# Visited = [ True  True False False False  True False False  True  True]
# # cust= 10
# Done  = False
# Total reward -193.0
# Action: 6
# Current Pos: [45 38]
# Next Post [14 45]
#  prev travel dist 193.0
# post travel dist 231.0
# Visited = [ True  True False  True False  True False False  True  True]
# # cust= 10
# Done  = False
# Total reward -231.0
# Action: 7
# Current Pos: [14 45]
# Next Post [25 43]
#  prev travel dist 231.0
# post travel dist 244.0
# Visited = [ True  True False  True False  True  True False  True  True]
# # cust= 10
# Done  = False
# Total reward -244.0
# Action: 4
# Current Pos: [25 43]
# Next Post [48 49]
#  prev travel dist 244.0
# post travel dist 273.0
# Visited = [ True  True False  True False  True  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -273.0
# Action: 2
# Current Pos: [48 49]
# Next Post [42 49]
#  prev travel dist 273.0
# post travel dist 279.0
# Visited = [ True  True False  True  True  True  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -279.0
# Action: 0
# Current Pos: [42 49]
# Next Post [27  8]
#  prev travel dist 279.0
# post travel dist 335.0
# Visited = [ True  True  True  True  True  True  True  True  True  True]
# # cust= 10
# Done  = True
# adding episode =  [1, 8, 9, 0, 5, 3, 6, 7, 4, 2, 0], valid = True, reward = -1789.0
# Action: 9
# Current Pos: [25. 25.]
# Next Post [40 33]
#  prev travel dist 0
# post travel dist 23.0
# Visited = [False False False False False False False False False False]
# # cust= 10
# Done  = False
# Total reward -23.0
# Action: 3
# Current Pos: [40 33]
# Next Post [45 38]
#  prev travel dist 23.0
# post travel dist 33.0
# Visited = [False False False False False False False False False  True]
# # cust= 10
# Done  = False
# Total reward -33.0
# Action: 7
# Current Pos: [45 38]
# Next Post [25 43]
#  prev travel dist 33.0
# post travel dist 58.0
# Visited = [False False False  True False False False False False  True]
# # cust= 10
# Done  = False
# Total reward -58.0
# Action: 0
# Current Pos: [25 43]
# Next Post [27  8]
#  prev travel dist 58.0
# post travel dist 95.0
# Visited = [False False False  True False False False  True False  True]
# # cust= 10
# Done  = False
# Total reward -95.0
# Action: 4
# Current Pos: [27  8]
# Next Post [48 49]
#  prev travel dist 95.0
# post travel dist 157.0
# Visited = [ True False False  True False False False  True False  True]
# # cust= 10
# Done  = False
# Total reward -157.0
# Action: 5
# Current Pos: [48 49]
# Next Post [18 34]
#  prev travel dist 157.0
# post travel dist 202.0
# Visited = [ True False False  True  True False False  True False  True]
# # cust= 10
# Done  = False
# Total reward -202.0
# Action: 6
# Current Pos: [18 34]
# Next Post [14 45]
#  prev travel dist 202.0
# post travel dist 217.0
# Visited = [ True False False  True  True  True False  True False  True]
# # cust= 10
# Done  = False
# Total reward -217.0
# Action: 2
# Current Pos: [14 45]
# Next Post [42 49]
#  prev travel dist 217.0
# post travel dist 249.0
# Visited = [ True False False  True  True  True  True  True False  True]
# # cust= 10
# Done  = False
# Total reward -249.0
# Action: 8
# Current Pos: [42 49]
# Next Post [23 22]
#  prev travel dist 249.0
# post travel dist 295.0
# Visited = [ True False  True  True  True  True  True  True False  True]
# # cust= 10
# Done  = False
# Total reward -295.0
# Action: 1
# Current Pos: [23 22]
# Next Post [10 40]
#  prev travel dist 295.0
# post travel dist 326.0
# Visited = [ True False  True  True  True  True  True  True  True  True]
# # cust= 10
# Done  = False
# Total reward -326.0
# Action: 0
# Current Pos: [10 40]
# Next Post [27  8]
#  prev travel dist 326.0
# post travel dist 375.0
# Visited = [ True  True  True  True  True  True  True  True  True  True]
# # cust= 10
# Done  = True
# adding episode =  [9, 3, 7, 0, 4, 5, 6, 2, 8, 1, 0], valid = True, reward = -1755.0
#
# Final Statistics:
# Best Distance Found: 312.00
# Average Distance: 367.60
# Completion Rate: 100.0%
#
# Best Route Details:
#
# Route Details:
# Number of customers visited: 10/10
#
# Step-by-step route:
# Start at depot: [25. 25.]
#
# Step 1:
# Visit customer 4 at position [48 49]
# Travel distance: 47.00
# Arrival time: 47.00
# Service start: 47.00
# Due time: 1000.00
# Current load: 11/200
#
# Step 2:
# Visit customer 2 at position [42 49]
# Travel distance: 6.00
# Arrival time: 63.00
# Service start: 63.00
# Due time: 1000.00
# Current load: 19/200
#
# Step 3:
# Visit customer 0 at position [27  8]
# Travel distance: 56.00
# Arrival time: 129.00
# Service start: 129.00
# Due time: 1000.00
# Current load: 41/200
#
# Step 4:
# Visit customer 8 at position [23 22]
# Travel distance: 18.00
# Arrival time: 157.00
# Service start: 157.00
# Due time: 1000.00
# Current load: 50/200
#
# Step 5:
# Visit customer 3 at position [45 38]
# Travel distance: 38.00
# Arrival time: 205.00
# Service start: 205.00
# Due time: 1000.00
# Current load: 65/200
#
# Step 6:
# Visit customer 9 at position [40 33]
# Travel distance: 10.00
# Arrival time: 225.00
# Service start: 225.00
# Due time: 1000.00
# Current load: 85/200
#
# Step 7:
# Visit customer 6 at position [14 45]
# Travel distance: 38.00
# Arrival time: 273.00
# Service start: 273.00
# Due time: 1000.00
# Current load: 89/200
#
# Step 8:
# Visit customer 7 at position [25 43]
# Travel distance: 13.00
# Arrival time: 296.00
# Service start: 296.00
# Due time: 1000.00
# Current load: 94/200
#
# Step 9:
# Visit customer 1 at position [10 40]
# Travel distance: 18.00
# Arrival time: 324.00
# Service start: 324.00
# Due time: 1000.00
# Current load: 97/200
#
# Step 10:
# Visit customer 5 at position [18 34]
# Travel distance: 14.00
# Arrival time: 348.00
# Service start: 348.00
# Due time: 1000.00
# Current load: 124/200
#
# Step 11:
# Visit customer 0 at position [27  8]
# Travel distance: 35.00
# Arrival time: 393.00
# Service start: 393.00
# Due time: 1000.00
# Current load: 146/200
#
# Return to depot:
# Final leg distance: 19.00
# Final arrival time: 422.00
#
# Total route distance: 312.00
# Total time: 422.00
# Total load: 146/200

# %%
class RLExperimentRunner:
    def __init__(self, env, sac_agent, maxent_agent, other_agents=None):
        self.env = env
        self.sac_agent = sac_agent
        self.maxent_agent = maxent_agent
        self.other_agents = other_agents or {}
        self.trackers = {
            'SAC': RouteTracker(),
            'MaxEnt': RouteTracker(),
        }
        for name in self.other_agents.keys():
            self.trackers[name] = RouteTracker()

    def run(self, episodes=100):
        for episode in range(episodes):
            print(f"Running Episode {episode + 1}/{episodes}")
            # Run SAC Agent
            self.run_agent(self.sac_agent, self.trackers['SAC'], "SAC")
            # Run MaxEnt Agent
            self.run_agent(self.maxent_agent, self.trackers['MaxEnt'], "MaxEnt")
            # Run Other Agents
            for name, agent in self.other_agents.items():
                self.run_agent(agent, self.trackers[name], name)

    def run_agent(self, agent, tracker, name):
        state = self.env.reset()
        route = []
        done = False
        episode_reward = 0

        while not done:
            action = agent.select_action(state)
            state, reward, done, _ = self.env.step(action)
            episode_reward += reward
            route.append(action)

        valid, msg = validate_route(self.env, route)
        if valid:
            tracker.add_episode(self.env, route, episode_reward)
        else:
            print(f"{name} Agent - Invalid Route: {msg}")

    def summarize_results(self):
        results = {}
        for name, tracker in self.trackers.items():
            print(f"\n{name} Results:")
            print(f"\n{tracker.episode_distances} episode:")
            stats = tracker.get_statistics()
            print(f"Average Distance: {stats['avg_distance']:.2f}")
            print(f"Best Distance: {stats['best_distance']:.2f}")
            print(f"Completion Rate: {stats['completion_rate'] * 100:.2f}%")
            print(f"Average Reward: {stats['avg_reward']:.2f}")
            results[name] = stats
        return results
def validate_route(env, route):
    """
    Validate if route is complete and feasible:
    1. All customers visited exactly once
    2. Valid customer indices
    3. Capacity constraints respected
    4. Time windows respected
    """
    # Access the wrapped environment
    vrp_env = env.env

    if not route:
        return False, "Empty route"

    # Check if all customers are visited exactly once
    visited = set(route)
    if len(visited) != vrp_env.num_customers:
        return False, f"Not all customers visited. Visited {len(visited)}/{vrp_env.num_customers}"

    # Check valid indices
    if any(i >= vrp_env.num_customers for i in route):
        return False, "Invalid customer index"

    # Check capacity constraints
    total_load = 0
    for customer_idx in route:
        total_load += vrp_env.demands[customer_idx]
        if total_load > vrp_env.vehicle_capacity:
            return False, "Capacity constraint violated"

    # Check time windows
    current_time = 0
    current_pos = vrp_env.depot.copy()

    for customer_idx in route:
        customer_pos = vrp_env.customers[customer_idx]
        travel_time = np.abs(current_pos - customer_pos).sum()

        arrival_time = current_time + travel_time
        if arrival_time > vrp_env.due_times[customer_idx]:
            return False, "Time window violated - arrived too late"

        service_start = max(arrival_time, vrp_env.ready_times[customer_idx])
        current_time = service_start + vrp_env.service_times[customer_idx]
        current_pos = customer_pos.copy()

    # Check return to depot
    final_time = current_time + np.abs(current_pos - vrp_env.depot).sum()
    if final_time > max(vrp_env.due_times):
        return False, "Cannot return to depot within time window"

    return True, "Valid route"

env = GymVRPEnvironment(num_customers=29, grid_size=50)
sac_agent = SACAgent(
    state_dim=env.observation_space.shape[0],
    action_dim=env.action_space.n )
maxent_agent = MaxEntRL(
     state_dim=env.observation_space.shape[0],
     action_dim=env.action_space.n
 )
other_agents = {
     #"NearestNeighbor": NearestNeighbor(),
     #"PPO": PPOAgent(env),
}
runner = RLExperimentRunner(env, sac_agent, maxent_agent, other_agents)
runner.run(episodes=50)
results = runner.summarize_results()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Streaming output truncated to the last 5000 lines.
# Visited = [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True False  True  True  True  True  True False  True  True  True
#  False  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -952.0
# Action: 20
# Current Pos: [40 20]
# Next Post [7 0]
#  prev travel dist 952.0
# post travel dist 1005.0
# Visited = [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True False  True  True  True
#  False  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -1005.0
# Action: 24
# Current Pos: [7 0]
# Next Post [ 5 30]
#  prev travel dist 1005.0
# post travel dist 1037.0
# Visited = [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -1037.0
# Action: 0
# Current Pos: [ 5 30]
# Next Post [19 15]
#  prev travel dist 1037.0
# post travel dist 1066.0
# Visited = [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = True
# SAC Agent - Invalid Route: Capacity constraint violated
# Action: 8
# Current Pos: [25. 25.]
# Next Post [18 39]
#  prev travel dist 0
# post travel dist 21.0
# Visited = [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -21.0
# Action: 2
# Current Pos: [18 39]
# Next Post [12 30]
#  prev travel dist 21.0
# post travel dist 36.0
# Visited = [False False False False False False False False  True False False False
#  False False False False False False False False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -36.0
# Action: 18
# Current Pos: [12 30]
# Next Post [21 13]
#  prev travel dist 36.0
# post travel dist 62.0
# Visited = [False False  True False False False False False  True False False False
#  False False False False False False False False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -62.0
# Action: 0
# Current Pos: [21 13]
# Next Post [19 15]
#  prev travel dist 62.0
# post travel dist 66.0
# Visited = [False False  True False False False False False  True False False False
#  False False False False False False  True False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -66.0
# Action: 3
# Current Pos: [19 15]
# Next Post [35 25]
#  prev travel dist 66.0
# post travel dist 92.0
# Visited = [ True False  True False False False False False  True False False False
#  False False False False False False  True False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -92.0
# Action: 15
# Current Pos: [35 25]
# Next Post [ 1 47]
#  prev travel dist 92.0
# post travel dist 148.0
# Visited = [ True False  True  True False False False False  True False False False
#  False False False False False False  True False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -148.0
# Action: 4
# Current Pos: [ 1 47]
# Next Post [29 23]
#  prev travel dist 148.0
# post travel dist 200.0
# Visited = [ True False  True  True False False False False  True False False False
#  False False False  True False False  True False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -200.0
# Action: 26
# Current Pos: [29 23]
# Next Post [22 11]
#  prev travel dist 200.0
# post travel dist 219.0
# Visited = [ True False  True  True  True False False False  True False False False
#  False False False  True False False  True False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -219.0
# Action: 16
# Current Pos: [22 11]
# Next Post [23  5]
#  prev travel dist 219.0
# post travel dist 226.0
# Visited = [ True False  True  True  True False False False  True False False False
#  False False False  True False False  True False False False False False
#  False False  True False False]
# # cust= 29
# Done  = False
# Total reward -226.0
# Action: 10
# Current Pos: [23  5]
# Next Post [49 14]
#  prev travel dist 226.0
# post travel dist 261.0
# Visited = [ True False  True  True  True False False False  True False False False
#  False False False  True  True False  True False False False False False
#  False False  True False False]
# # cust= 29
# Done  = False
# Total reward -261.0
# Action: 6
# Current Pos: [49 14]
# Next Post [49 42]
#  prev travel dist 261.0
# post travel dist 289.0
# Visited = [ True False  True  True  True False False False  True False  True False
#  False False False  True  True False  True False False False False False
#  False False  True False False]
# # cust= 29
# Done  = False
# Total reward -289.0
# Action: 24
# Current Pos: [49 42]
# Next Post [ 5 30]
#  prev travel dist 289.0
# post travel dist 345.0
# Visited = [ True False  True  True  True False  True False  True False  True False
#  False False False  True  True False  True False False False False False
#  False False  True False False]
# # cust= 29
# Done  = False
# Total reward -345.0
# Action: 21
# Current Pos: [ 5 30]
# Next Post [44 22]
#  prev travel dist 345.0
# post travel dist 392.0
# Visited = [ True False  True  True  True False  True False  True False  True False
#  False False False  True  True False  True False False False False False
#   True False  True False False]
# # cust= 29
# Done  = False
# Total reward -392.0
# Action: 23
# Current Pos: [44 22]
# Next Post [14  5]
#  prev travel dist 392.0
# post travel dist 439.0
# Visited = [ True False  True  True  True False  True False  True False  True False
#  False False False  True  True False  True False False  True False False
#   True False  True False False]
# # cust= 29
# Done  = False
# Total reward -439.0
# Action: 27
# Current Pos: [14  5]
# Next Post [ 8 45]
#  prev travel dist 439.0
# post travel dist 485.0
# Visited = [ True False  True  True  True False  True False  True False  True False
#  False False False  True  True False  True False False  True False  True
#   True False  True False False]
# # cust= 29
# Done  = False
# Total reward -485.0
# Action: 20
# Current Pos: [ 8 45]
# Next Post [7 0]
#  prev travel dist 485.0
# post travel dist 531.0
# Visited = [ True False  True  True  True False  True False  True False  True False
#  False False False  True  True False  True False False  True False  True
#   True False  True  True False]
# # cust= 29
# Done  = False
# Total reward -531.0
# Action: 14
# Current Pos: [7 0]
# Next Post [40 20]
#  prev travel dist 531.0
# post travel dist 584.0
# Visited = [ True False  True  True  True False  True False  True False  True False
#  False False False  True  True False  True False  True  True False  True
#   True False  True  True False]
# # cust= 29
# Done  = False
# Total reward -584.0
# Action: 5
# Current Pos: [40 20]
# Next Post [8 5]
#  prev travel dist 584.0
# post travel dist 631.0
# Visited = [ True False  True  True  True False  True False  True False  True False
#  False False  True  True  True False  True False  True  True False  True
#   True False  True  True False]
# # cust= 29
# Done  = False
# Total reward -631.0
# Action: 13
# Current Pos: [8 5]
# Next Post [26  0]
#  prev travel dist 631.0
# post travel dist 654.0
# Visited = [ True False  True  True  True  True  True False  True False  True False
#  False False  True  True  True False  True False  True  True False  True
#   True False  True  True False]
# # cust= 29
# Done  = False
# Total reward -654.0
# Action: 12
# Current Pos: [26  0]
# Next Post [10 41]
#  prev travel dist 654.0
# post travel dist 711.0
# Visited = [ True False  True  True  True  True  True False  True False  True False
#  False  True  True  True  True False  True False  True  True False  True
#   True False  True  True False]
# # cust= 29
# Done  = False
# Total reward -711.0
# Action: 1
# Current Pos: [10 41]
# Next Post [33 36]
#  prev travel dist 711.0
# post travel dist 739.0
# Visited = [ True False  True  True  True  True  True False  True False  True False
#   True  True  True  True  True False  True False  True  True False  True
#   True False  True  True False]
# # cust= 29
# Done  = False
# Total reward -739.0
# Action: 22
# Current Pos: [33 36]
# Next Post [11 30]
#  prev travel dist 739.0
# post travel dist 767.0
# Visited = [ True  True  True  True  True  True  True False  True False  True False
#   True  True  True  True  True False  True False  True  True False  True
#   True False  True  True False]
# # cust= 29
# Done  = False
# Total reward -767.0
# Action: 28
# Current Pos: [11 30]
# Next Post [36 20]
#  prev travel dist 767.0
# post travel dist 802.0
# Visited = [ True  True  True  True  True  True  True False  True False  True False
#   True  True  True  True  True False  True False  True  True  True  True
#   True False  True  True False]
# # cust= 29
# Done  = False
# Total reward -802.0
# Action: 11
# Current Pos: [36 20]
# Next Post [42 40]
#  prev travel dist 802.0
# post travel dist 828.0
# Visited = [ True  True  True  True  True  True  True False  True False  True False
#   True  True  True  True  True False  True False  True  True  True  True
#   True False  True  True  True]
# # cust= 29
# Done  = False
# Total reward -828.0
# Action: 7
# Current Pos: [42 40]
# Next Post [11  8]
#  prev travel dist 828.0
# post travel dist 891.0
# Visited = [ True  True  True  True  True  True  True False  True False  True  True
#   True  True  True  True  True False  True False  True  True  True  True
#   True False  True  True  True]
# # cust= 29
# Done  = False
# Total reward -891.0
# Action: 9
# Current Pos: [11  8]
# Next Post [21 43]
#  prev travel dist 891.0
# post travel dist 936.0
# Visited = [ True  True  True  True  True  True  True  True  True False  True  True
#   True  True  True  True  True False  True False  True  True  True  True
#   True False  True  True  True]
# # cust= 29
# Done  = False
# Total reward -936.0
# Action: 17
# Current Pos: [21 43]
# Next Post [47 37]
#  prev travel dist 936.0
# post travel dist 968.0
# Visited = [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False  True False  True  True  True  True
#   True False  True  True  True]
# # cust= 29
# Done  = False
# Total reward -968.0
# Action: 19
# Current Pos: [47 37]
# Next Post [20  1]
#  prev travel dist 968.0
# post travel dist 1031.0
# Visited = [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True False  True  True  True  True
#   True False  True  True  True]
# # cust= 29
# Done  = False
# Total reward -1031.0
# Action: 25
# Current Pos: [20  1]
# Next Post [12 24]
#  prev travel dist 1031.0
# post travel dist 1062.0
# Visited = [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True False  True  True  True]
# # cust= 29
# Done  = False
# Total reward -1062.0
# Action: 0
# Current Pos: [12 24]
# Next Post [19 15]
#  prev travel dist 1062.0
# post travel dist 1078.0
# Visited = [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = True
# MaxEnt Agent - Invalid Route: Capacity constraint violated
# Running Episode 44/50
# Action: 8
# Current Pos: [25. 25.]
# Next Post [18 39]
#  prev travel dist 0
# post travel dist 21.0
# Visited = [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -21.0
# Action: 18
# Current Pos: [18 39]
# Next Post [21 13]
#  prev travel dist 21.0
# post travel dist 50.0
# Visited = [False False False False False False False False  True False False False
#  False False False False False False False False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -50.0
# Action: 16
# Current Pos: [21 13]
# Next Post [23  5]
#  prev travel dist 50.0
# post travel dist 60.0
# Visited = [False False False False False False False False  True False False False
#  False False False False False False  True False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -60.0
# Action: 24
# Current Pos: [23  5]
# Next Post [ 5 30]
#  prev travel dist 60.0
# post travel dist 103.0
# Visited = [False False False False False False False False  True False False False
#  False False False False  True False  True False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -103.0
# Action: 25
# Current Pos: [ 5 30]
# Next Post [12 24]
#  prev travel dist 103.0
# post travel dist 116.0
# Visited = [False False False False False False False False  True False False False
#  False False False False  True False  True False False False False False
#   True False False False False]
# # cust= 29
# Done  = False
# Total reward -116.0
# Action: 19
# Current Pos: [12 24]
# Next Post [20  1]
#  prev travel dist 116.0
# post travel dist 147.0
# Visited = [False False False False False False False False  True False False False
#  False False False False  True False  True False False False False False
#   True  True False False False]
# # cust= 29
# Done  = False
# Total reward -147.0
# Action: 23
# Current Pos: [20  1]
# Next Post [14  5]
#  prev travel dist 147.0
# post travel dist 157.0
# Visited = [False False False False False False False False  True False False False
#  False False False False  True False  True  True False False False False
#   True  True False False False]
# # cust= 29
# Done  = False
# Total reward -157.0
# Action: 26
# Current Pos: [14  5]
# Next Post [22 11]
#  prev travel dist 157.0
# post travel dist 171.0
# Visited = [False False False False False False False False  True False False False
#  False False False False  True False  True  True False False False  True
#   True  True False False False]
# # cust= 29
# Done  = False
# Total reward -171.0
# Action: 0
# Current Pos: [22 11]
# Next Post [19 15]
#  prev travel dist 171.0
# post travel dist 178.0
# Visited = [False False False False False False False False  True False False False
#  False False False False  True False  True  True False False False  True
#   True  True  True False False]
# # cust= 29
# Done  = False
# Total reward -178.0
# Action: 27
# Current Pos: [19 15]
# Next Post [ 8 45]
#  prev travel dist 178.0
# post travel dist 219.0
# Visited = [ True False False False False False False False  True False False False
#  False False False False  True False  True  True False False False  True
#   True  True  True False False]
# # cust= 29
# Done  = False
# Total reward -219.0
# Action: 20
# Current Pos: [ 8 45]
# Next Post [7 0]
#  prev travel dist 219.0
# post travel dist 265.0
# Visited = [ True False False False False False False False  True False False False
#  False False False False  True False  True  True False False False  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -265.0
# Action: 1
# Current Pos: [7 0]
# Next Post [33 36]
#  prev travel dist 265.0
# post travel dist 327.0
# Visited = [ True False False False False False False False  True False False False
#  False False False False  True False  True  True  True False False  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -327.0
# Action: 4
# Current Pos: [33 36]
# Next Post [29 23]
#  prev travel dist 327.0
# post travel dist 344.0
# Visited = [ True  True False False False False False False  True False False False
#  False False False False  True False  True  True  True False False  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -344.0
# Action: 12
# Current Pos: [29 23]
# Next Post [10 41]
#  prev travel dist 344.0
# post travel dist 381.0
# Visited = [ True  True False False  True False False False  True False False False
#  False False False False  True False  True  True  True False False  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -381.0
# Action: 11
# Current Pos: [10 41]
# Next Post [42 40]
#  prev travel dist 381.0
# post travel dist 414.0
# Visited = [ True  True False False  True False False False  True False False False
#   True False False False  True False  True  True  True False False  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -414.0
# Action: 10
# Current Pos: [42 40]
# Next Post [49 14]
#  prev travel dist 414.0
# post travel dist 447.0
# Visited = [ True  True False False  True False False False  True False False  True
#   True False False False  True False  True  True  True False False  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -447.0
# Action: 2
# Current Pos: [49 14]
# Next Post [12 30]
#  prev travel dist 447.0
# post travel dist 500.0
# Visited = [ True  True False False  True False False False  True False  True  True
#   True False False False  True False  True  True  True False False  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -500.0
# Action: 3
# Current Pos: [12 30]
# Next Post [35 25]
#  prev travel dist 500.0
# post travel dist 528.0
# Visited = [ True  True  True False  True False False False  True False  True  True
#   True False False False  True False  True  True  True False False  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -528.0
# Action: 15
# Current Pos: [35 25]
# Next Post [ 1 47]
#  prev travel dist 528.0
# post travel dist 584.0
# Visited = [ True  True  True  True  True False False False  True False  True  True
#   True False False False  True False  True  True  True False False  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -584.0
# Action: 22
# Current Pos: [ 1 47]
# Next Post [11 30]
#  prev travel dist 584.0
# post travel dist 611.0
# Visited = [ True  True  True  True  True False False False  True False  True  True
#   True False False  True  True False  True  True  True False False  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -611.0
# Action: 7
# Current Pos: [11 30]
# Next Post [11  8]
#  prev travel dist 611.0
# post travel dist 633.0
# Visited = [ True  True  True  True  True False False False  True False  True  True
#   True False False  True  True False  True  True  True False  True  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -633.0
# Action: 21
# Current Pos: [11  8]
# Next Post [44 22]
#  prev travel dist 633.0
# post travel dist 680.0
# Visited = [ True  True  True  True  True False False  True  True False  True  True
#   True False False  True  True False  True  True  True False  True  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -680.0
# Action: 5
# Current Pos: [44 22]
# Next Post [8 5]
#  prev travel dist 680.0
# post travel dist 733.0
# Visited = [ True  True  True  True  True False False  True  True False  True  True
#   True False False  True  True False  True  True  True  True  True  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -733.0
# Action: 6
# Current Pos: [8 5]
# Next Post [49 42]
#  prev travel dist 733.0
# post travel dist 811.0
# Visited = [ True  True  True  True  True  True False  True  True False  True  True
#   True False False  True  True False  True  True  True  True  True  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -811.0
# Action: 14
# Current Pos: [49 42]
# Next Post [40 20]
#  prev travel dist 811.0
# post travel dist 842.0
# Visited = [ True  True  True  True  True  True  True  True  True False  True  True
#   True False False  True  True False  True  True  True  True  True  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -842.0
# Action: 13
# Current Pos: [40 20]
# Next Post [26  0]
#  prev travel dist 842.0
# post travel dist 876.0
# Visited = [ True  True  True  True  True  True  True  True  True False  True  True
#   True False  True  True  True False  True  True  True  True  True  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -876.0
# Action: 28
# Current Pos: [26  0]
# Next Post [36 20]
#  prev travel dist 876.0
# post travel dist 906.0
# Visited = [ True  True  True  True  True  True  True  True  True False  True  True
#   True  True  True  True  True False  True  True  True  True  True  True
#   True  True  True  True False]
# # cust= 29
# Done  = False
# Total reward -906.0
# Action: 17
# Current Pos: [36 20]
# Next Post [47 37]
#  prev travel dist 906.0
# post travel dist 934.0
# Visited = [ True  True  True  True  True  True  True  True  True False  True  True
#   True  True  True  True  True False  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -934.0
# Action: 9
# Current Pos: [47 37]
# Next Post [21 43]
#  prev travel dist 934.0
# post travel dist 966.0
# Visited = [ True  True  True  True  True  True  True  True  True False  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -966.0
# Action: 0
# Current Pos: [21 43]
# Next Post [19 15]
#  prev travel dist 966.0
# post travel dist 996.0
# Visited = [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = True
# SAC Agent - Invalid Route: Capacity constraint violated
# Action: 8
# Current Pos: [25. 25.]
# Next Post [18 39]
#  prev travel dist 0
# post travel dist 21.0
# Visited = [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -21.0
# Action: 24
# Current Pos: [18 39]
# Next Post [ 5 30]
#  prev travel dist 21.0
# post travel dist 43.0
# Visited = [False False False False False False False False  True False False False
#  False False False False False False False False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -43.0
# Action: 1
# Current Pos: [ 5 30]
# Next Post [33 36]
#  prev travel dist 43.0
# post travel dist 77.0
# Visited = [False False False False False False False False  True False False False
#  False False False False False False False False False False False False
#   True False False False False]
# # cust= 29
# Done  = False
# Total reward -77.0
# Action: 10
# Current Pos: [33 36]
# Next Post [49 14]
#  prev travel dist 77.0
# post travel dist 115.0
# Visited = [False  True False False False False False False  True False False False
#  False False False False False False False False False False False False
#   True False False False False]
# # cust= 29
# Done  = False
# Total reward -115.0
# Action: 11
# Current Pos: [49 14]
# Next Post [42 40]
#  prev travel dist 115.0
# post travel dist 148.0
# Visited = [False  True False False False False False False  True False  True False
#  False False False False False False False False False False False False
#   True False False False False]
# # cust= 29
# Done  = False
# Total reward -148.0
# Action: 6
# Current Pos: [42 40]
# Next Post [49 42]
#  prev travel dist 148.0
# post travel dist 157.0
# Visited = [False  True False False False False False False  True False  True  True
#  False False False False False False False False False False False False
#   True False False False False]
# # cust= 29
# Done  = False
# Total reward -157.0
# Action: 18
# Current Pos: [49 42]
# Next Post [21 13]
#  prev travel dist 157.0
# post travel dist 214.0
# Visited = [False  True False False False False  True False  True False  True  True
#  False False False False False False False False False False False False
#   True False False False False]
# # cust= 29
# Done  = False
# Total reward -214.0
# Action: 4
# Current Pos: [21 13]
# Next Post [29 23]
#  prev travel dist 214.0
# post travel dist 232.0
# Visited = [False  True False False False False  True False  True False  True  True
#  False False False False False False  True False False False False False
#   True False False False False]
# # cust= 29
# Done  = False
# Total reward -232.0
# Action: 28
# Current Pos: [29 23]
# Next Post [36 20]
#  prev travel dist 232.0
# post travel dist 242.0
# Visited = [False  True False False  True False  True False  True False  True  True
#  False False False False False False  True False False False False False
#   True False False False False]
# # cust= 29
# Done  = False
# Total reward -242.0
# Action: 22
# Current Pos: [36 20]
# Next Post [11 30]
#  prev travel dist 242.0
# post travel dist 277.0
# Visited = [False  True False False  True False  True False  True False  True  True
#  False False False False False False  True False False False False False
#   True False False False  True]
# # cust= 29
# Done  = False
# Total reward -277.0
# Action: 23
# Current Pos: [11 30]
# Next Post [14  5]
#  prev travel dist 277.0
# post travel dist 305.0
# Visited = [False  True False False  True False  True False  True False  True  True
#  False False False False False False  True False False False  True False
#   True False False False  True]
# # cust= 29
# Done  = False
# Total reward -305.0
# Action: 20
# Current Pos: [14  5]
# Next Post [7 0]
#  prev travel dist 305.0
# post travel dist 317.0
# Visited = [False  True False False  True False  True False  True False  True  True
#  False False False False False False  True False False False  True  True
#   True False False False  True]
# # cust= 29
# Done  = False
# Total reward -317.0
# Action: 9
# Current Pos: [7 0]
# Next Post [21 43]
#  prev travel dist 317.0
# post travel dist 374.0
# Visited = [False  True False False  True False  True False  True False  True  True
#  False False False False False False  True False  True False  True  True
#   True False False False  True]
# # cust= 29
# Done  = False
# Total reward -374.0
# Action: 21
# Current Pos: [21 43]
# Next Post [44 22]
#  prev travel dist 374.0
# post travel dist 418.0
# Visited = [False  True False False  True False  True False  True  True  True  True
#  False False False False False False  True False  True False  True  True
#   True False False False  True]
# # cust= 29
# Done  = False
# Total reward -418.0
# Action: 27
# Current Pos: [44 22]
# Next Post [ 8 45]
#  prev travel dist 418.0
# post travel dist 477.0
# Visited = [False  True False False  True False  True False  True  True  True  True
#  False False False False False False  True False  True  True  True  True
#   True False False False  True]
# # cust= 29
# Done  = False
# Total reward -477.0
# Action: 15
# Current Pos: [ 8 45]
# Next Post [ 1 47]
#  prev travel dist 477.0
# post travel dist 486.0
# Visited = [False  True False False  True False  True False  True  True  True  True
#  False False False False False False  True False  True  True  True  True
#   True False False  True  True]
# # cust= 29
# Done  = False
# Total reward -486.0
# Action: 7
# Current Pos: [ 1 47]
# Next Post [11  8]
#  prev travel dist 486.0
# post travel dist 535.0
# Visited = [False  True False False  True False  True False  True  True  True  True
#  False False False  True False False  True False  True  True  True  True
#   True False False  True  True]
# # cust= 29
# Done  = False
# Total reward -535.0
# Action: 13
# Current Pos: [11  8]
# Next Post [26  0]
#  prev travel dist 535.0
# post travel dist 558.0
# Visited = [False  True False False  True False  True  True  True  True  True  True
#  False False False  True False False  True False  True  True  True  True
#   True False False  True  True]
# # cust= 29
# Done  = False
# Total reward -558.0
# Action: 17
# Current Pos: [26  0]
# Next Post [47 37]
#  prev travel dist 558.0
# post travel dist 616.0
# Visited = [False  True False False  True False  True  True  True  True  True  True
#  False  True False  True False False  True False  True  True  True  True
#   True False False  True  True]
# # cust= 29
# Done  = False
# Total reward -616.0
# Action: 5
# Current Pos: [47 37]
# Next Post [8 5]
#  prev travel dist 616.0
# post travel dist 687.0
# Visited = [False  True False False  True False  True  True  True  True  True  True
#  False  True False  True False  True  True False  True  True  True  True
#   True False False  True  True]
# # cust= 29
# Done  = False
# Total reward -687.0
# Action: 25
# Current Pos: [8 5]
# Next Post [12 24]
#  prev travel dist 687.0
# post travel dist 710.0
# Visited = [False  True False False  True  True  True  True  True  True  True  True
#  False  True False  True False  True  True False  True  True  True  True
#   True False False  True  True]
# # cust= 29
# Done  = False
# Total reward -710.0
# Action: 26
# Current Pos: [12 24]
# Next Post [22 11]
#  prev travel dist 710.0
# post travel dist 733.0
# Visited = [False  True False False  True  True  True  True  True  True  True  True
#  False  True False  True False  True  True False  True  True  True  True
#   True  True False  True  True]
# # cust= 29
# Done  = False
# Total reward -733.0
# Action: 14
# Current Pos: [22 11]
# Next Post [40 20]
#  prev travel dist 733.0
# post travel dist 760.0
# Visited = [False  True False False  True  True  True  True  True  True  True  True
#  False  True False  True False  True  True False  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -760.0
# Action: 3
# Current Pos: [40 20]
# Next Post [35 25]
#  prev travel dist 760.0
# post travel dist 770.0
# Visited = [False  True False False  True  True  True  True  True  True  True  True
#  False  True  True  True False  True  True False  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -770.0
# Action: 19
# Current Pos: [35 25]
# Next Post [20  1]
#  prev travel dist 770.0
# post travel dist 809.0
# Visited = [False  True False  True  True  True  True  True  True  True  True  True
#  False  True  True  True False  True  True False  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -809.0
# Action: 12
# Current Pos: [20  1]
# Next Post [10 41]
#  prev travel dist 809.0
# post travel dist 859.0
# Visited = [False  True False  True  True  True  True  True  True  True  True  True
#  False  True  True  True False  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -859.0
# Action: 16
# Current Pos: [10 41]
# Next Post [23  5]
#  prev travel dist 859.0
# post travel dist 908.0
# Visited = [False  True False  True  True  True  True  True  True  True  True  True
#   True  True  True  True False  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -908.0
# Action: 2
# Current Pos: [23  5]
# Next Post [12 30]
#  prev travel dist 908.0
# post travel dist 944.0
# Visited = [False  True False  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -944.0
# Action: 0
# Current Pos: [12 30]
# Next Post [19 15]
#  prev travel dist 944.0
# post travel dist 966.0
# Visited = [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -966.0
# Action: 0
# Current Pos: [19 15]
# Next Post [19 15]
#  prev travel dist 966.0
# post travel dist 966.0
# Visited = [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = True
# MaxEnt Agent - Invalid Route: Capacity constraint violated
# Running Episode 45/50
# Action: 16
# Current Pos: [25. 25.]
# Next Post [23  5]
#  prev travel dist 0
# post travel dist 22.0
# Visited = [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -22.0
# Action: 15
# Current Pos: [23  5]
# Next Post [ 1 47]
#  prev travel dist 22.0
# post travel dist 86.0
# Visited = [False False False False False False False False False False False False
#  False False False False  True False False False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -86.0
# Action: 21
# Current Pos: [ 1 47]
# Next Post [44 22]
#  prev travel dist 86.0
# post travel dist 154.0
# Visited = [False False False False False False False False False False False False
#  False False False  True  True False False False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -154.0
# Action: 13
# Current Pos: [44 22]
# Next Post [26  0]
#  prev travel dist 154.0
# post travel dist 194.0
# Visited = [False False False False False False False False False False False False
#  False False False  True  True False False False False  True False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -194.0
# Action: 27
# Current Pos: [26  0]
# Next Post [ 8 45]
#  prev travel dist 194.0
# post travel dist 257.0
# Visited = [False False False False False False False False False False False False
#  False  True False  True  True False False False False  True False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -257.0
# Action: 28
# Current Pos: [ 8 45]
# Next Post [36 20]
#  prev travel dist 257.0
# post travel dist 310.0
# Visited = [False False False False False False False False False False False False
#  False  True False  True  True False False False False  True False False
#  False False False  True False]
# # cust= 29
# Done  = False
# Total reward -310.0
# Action: 3
# Current Pos: [36 20]
# Next Post [35 25]
#  prev travel dist 310.0
# post travel dist 316.0
# Visited = [False False False False False False False False False False False False
#  False  True False  True  True False False False False  True False False
#  False False False  True  True]
# # cust= 29
# Done  = False
# Total reward -316.0
# Action: 18
# Current Pos: [35 25]
# Next Post [21 13]
#  prev travel dist 316.0
# post travel dist 342.0
# Visited = [False False False  True False False False False False False False False
#  False  True False  True  True False False False False  True False False
#  False False False  True  True]
# # cust= 29
# Done  = False
# Total reward -342.0
# Action: 9
# Current Pos: [21 13]
# Next Post [21 43]
#  prev travel dist 342.0
# post travel dist 372.0
# Visited = [False False False  True False False False False False False False False
#  False  True False  True  True False  True False False  True False False
#  False False False  True  True]
# # cust= 29
# Done  = False
# Total reward -372.0
# Action: 20
# Current Pos: [21 43]
# Next Post [7 0]
#  prev travel dist 372.0
# post travel dist 429.0
# Visited = [False False False  True False False False False False  True False False
#  False  True False  True  True False  True False False  True False False
#  False False False  True  True]
# # cust= 29
# Done  = False
# Total reward -429.0
# Action: 1
# Current Pos: [7 0]
# Next Post [33 36]
#  prev travel dist 429.0
# post travel dist 491.0
# Visited = [False False False  True False False False False False  True False False
#  False  True False  True  True False  True False  True  True False False
#  False False False  True  True]
# # cust= 29
# Done  = False
# Total reward -491.0
# Action: 12
# Current Pos: [33 36]
# Next Post [10 41]
#  prev travel dist 491.0
# post travel dist 519.0
# Visited = [False  True False  True False False False False False  True False False
#  False  True False  True  True False  True False  True  True False False
#  False False False  True  True]
# # cust= 29
# Done  = False
# Total reward -519.0
# Action: 4
# Current Pos: [10 41]
# Next Post [29 23]
#  prev travel dist 519.0
# post travel dist 556.0
# Visited = [False  True False  True False False False False False  True False False
#   True  True False  True  True False  True False  True  True False False
#  False False False  True  True]
# # cust= 29
# Done  = False
# Total reward -556.0
# Action: 8
# Current Pos: [29 23]
# Next Post [18 39]
#  prev travel dist 556.0
# post travel dist 583.0
# Visited = [False  True False  True  True False False False False  True False False
#   True  True False  True  True False  True False  True  True False False
#  False False False  True  True]
# # cust= 29
# Done  = False
# Total reward -583.0
# Action: 25
# Current Pos: [18 39]
# Next Post [12 24]
#  prev travel dist 583.0
# post travel dist 604.0
# Visited = [False  True False  True  True False False False  True  True False False
#   True  True False  True  True False  True False  True  True False False
#  False False False  True  True]
# # cust= 29
# Done  = False
# Total reward -604.0
# Action: 0
# Current Pos: [12 24]
# Next Post [19 15]
#  prev travel dist 604.0
# post travel dist 620.0
# Visited = [False  True False  True  True False False False  True  True False False
#   True  True False  True  True False  True False  True  True False False
#  False  True False  True  True]
# # cust= 29
# Done  = False
# Total reward -620.0
# Action: 10
# Current Pos: [19 15]
# Next Post [49 14]
#  prev travel dist 620.0
# post travel dist 651.0
# Visited = [ True  True False  True  True False False False  True  True False False
#   True  True False  True  True False  True False  True  True False False
#  False  True False  True  True]
# # cust= 29
# Done  = False
# Total reward -651.0
# Action: 23
# Current Pos: [49 14]
# Next Post [14  5]
#  prev travel dist 651.0
# post travel dist 695.0
# Visited = [ True  True False  True  True False False False  True  True  True False
#   True  True False  True  True False  True False  True  True False False
#  False  True False  True  True]
# # cust= 29
# Done  = False
# Total reward -695.0
# Action: 11
# Current Pos: [14  5]
# Next Post [42 40]
#  prev travel dist 695.0
# post travel dist 758.0
# Visited = [ True  True False  True  True False False False  True  True  True False
#   True  True False  True  True False  True False  True  True False  True
#  False  True False  True  True]
# # cust= 29
# Done  = False
# Total reward -758.0
# Action: 26
# Current Pos: [42 40]
# Next Post [22 11]
#  prev travel dist 758.0
# post travel dist 807.0
# Visited = [ True  True False  True  True False False False  True  True  True  True
#   True  True False  True  True False  True False  True  True False  True
#  False  True False  True  True]
# # cust= 29
# Done  = False
# Total reward -807.0
# Action: 17
# Current Pos: [22 11]
# Next Post [47 37]
#  prev travel dist 807.0
# post travel dist 858.0
# Visited = [ True  True False  True  True False False False  True  True  True  True
#   True  True False  True  True False  True False  True  True False  True
#  False  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -858.0
# Action: 24
# Current Pos: [47 37]
# Next Post [ 5 30]
#  prev travel dist 858.0
# post travel dist 907.0
# Visited = [ True  True False  True  True False False False  True  True  True  True
#   True  True False  True  True  True  True False  True  True False  True
#  False  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -907.0
# Action: 6
# Current Pos: [ 5 30]
# Next Post [49 42]
#  prev travel dist 907.0
# post travel dist 963.0
# Visited = [ True  True False  True  True False False False  True  True  True  True
#   True  True False  True  True  True  True False  True  True False  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -963.0
# Action: 14
# Current Pos: [49 42]
# Next Post [40 20]
#  prev travel dist 963.0
# post travel dist 994.0
# Visited = [ True  True False  True  True False  True False  True  True  True  True
#   True  True False  True  True  True  True False  True  True False  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -994.0
# Action: 7
# Current Pos: [40 20]
# Next Post [11  8]
#  prev travel dist 994.0
# post travel dist 1035.0
# Visited = [ True  True False  True  True False  True False  True  True  True  True
#   True  True  True  True  True  True  True False  True  True False  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -1035.0
# Action: 19
# Current Pos: [11  8]
# Next Post [20  1]
#  prev travel dist 1035.0
# post travel dist 1051.0
# Visited = [ True  True False  True  True False  True  True  True  True  True  True
#   True  True  True  True  True  True  True False  True  True False  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -1051.0
# Action: 5
# Current Pos: [20  1]
# Next Post [8 5]
#  prev travel dist 1051.0
# post travel dist 1067.0
# Visited = [ True  True False  True  True False  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True False  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -1067.0
# Action: 2
# Current Pos: [8 5]
# Next Post [12 30]
#  prev travel dist 1067.0
# post travel dist 1096.0
# Visited = [ True  True False  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True False  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -1096.0
# Action: 22
# Current Pos: [12 30]
# Next Post [11 30]
#  prev travel dist 1096.0
# post travel dist 1097.0
# Visited = [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True False  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -1097.0
# Action: 0
# Current Pos: [11 30]
# Next Post [19 15]
#  prev travel dist 1097.0
# post travel dist 1120.0
# Visited = [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = True
# SAC Agent - Invalid Route: Capacity constraint violated
# Action: 26
# Current Pos: [25. 25.]
# Next Post [22 11]
#  prev travel dist 0
# post travel dist 17.0
# Visited = [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -17.0
# Action: 13
# Current Pos: [22 11]
# Next Post [26  0]
#  prev travel dist 17.0
# post travel dist 32.0
# Visited = [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False  True False False]
# # cust= 29
# Done  = False
# Total reward -32.0
# Action: 17
# Current Pos: [26  0]
# Next Post [47 37]
#  prev travel dist 32.0
# post travel dist 90.0
# Visited = [False False False False False False False False False False False False
#  False  True False False False False False False False False False False
#  False False  True False False]
# # cust= 29
# Done  = False
# Total reward -90.0
# Action: 28
# Current Pos: [47 37]
# Next Post [36 20]
#  prev travel dist 90.0
# post travel dist 118.0
# Visited = [False False False False False False False False False False False False
#  False  True False False False  True False False False False False False
#  False False  True False False]
# # cust= 29
# Done  = False
# Total reward -118.0
# Action: 18
# Current Pos: [36 20]
# Next Post [21 13]
#  prev travel dist 118.0
# post travel dist 140.0
# Visited = [False False False False False False False False False False False False
#  False  True False False False  True False False False False False False
#  False False  True False  True]
# # cust= 29
# Done  = False
# Total reward -140.0
# Action: 15
# Current Pos: [21 13]
# Next Post [ 1 47]
#  prev travel dist 140.0
# post travel dist 194.0
# Visited = [False False False False False False False False False False False False
#  False  True False False False  True  True False False False False False
#  False False  True False  True]
# # cust= 29
# Done  = False
# Total reward -194.0
# Action: 4
# Current Pos: [ 1 47]
# Next Post [29 23]
#  prev travel dist 194.0
# post travel dist 246.0
# Visited = [False False False False False False False False False False False False
#  False  True False  True False  True  True False False False False False
#  False False  True False  True]
# # cust= 29
# Done  = False
# Total reward -246.0
# Action: 12
# Current Pos: [29 23]
# Next Post [10 41]
#  prev travel dist 246.0
# post travel dist 283.0
# Visited = [False False False False  True False False False False False False False
#  False  True False  True False  True  True False False False False False
#  False False  True False  True]
# # cust= 29
# Done  = False
# Total reward -283.0
# Action: 6
# Current Pos: [10 41]
# Next Post [49 42]
#  prev travel dist 283.0
# post travel dist 323.0
# Visited = [False False False False  True False False False False False False False
#   True  True False  True False  True  True False False False False False
#  False False  True False  True]
# # cust= 29
# Done  = False
# Total reward -323.0
# Action: 2
# Current Pos: [49 42]
# Next Post [12 30]
#  prev travel dist 323.0
# post travel dist 372.0
# Visited = [False False False False  True False  True False False False False False
#   True  True False  True False  True  True False False False False False
#  False False  True False  True]
# # cust= 29
# Done  = False
# Total reward -372.0
# Action: 19
# Current Pos: [12 30]
# Next Post [20  1]
#  prev travel dist 372.0
# post travel dist 409.0
# Visited = [False False  True False  True False  True False False False False False
#   True  True False  True False  True  True False False False False False
#  False False  True False  True]
# # cust= 29
# Done  = False
# Total reward -409.0
# Action: 20
# Current Pos: [20  1]
# Next Post [7 0]
#  prev travel dist 409.0
# post travel dist 423.0
# Visited = [False False  True False  True False  True False False False False False
#   True  True False  True False  True  True  True False False False False
#  False False  True False  True]
# # cust= 29
# Done  = False
# Total reward -423.0
# Action: 7
# Current Pos: [7 0]
# Next Post [11  8]
#  prev travel dist 423.0
# post travel dist 435.0
# Visited = [False False  True False  True False  True False False False False False
#   True  True False  True False  True  True  True  True False False False
#  False False  True False  True]
# # cust= 29
# Done  = False
# Total reward -435.0
# Action: 8
# Current Pos: [11  8]
# Next Post [18 39]
#  prev travel dist 435.0
# post travel dist 473.0
# Visited = [False False  True False  True False  True  True False False False False
#   True  True False  True False  True  True  True  True False False False
#  False False  True False  True]
# # cust= 29
# Done  = False
# Total reward -473.0
# Action: 11
# Current Pos: [18 39]
# Next Post [42 40]
#  prev travel dist 473.0
# post travel dist 498.0
# Visited = [False False  True False  True False  True  True  True False False False
#   True  True False  True False  True  True  True  True False False False
#  False False  True False  True]
# # cust= 29
# Done  = False
# Total reward -498.0
# Action: 23
# Current Pos: [42 40]
# Next Post [14  5]
#  prev travel dist 498.0
# post travel dist 561.0
# Visited = [False False  True False  True False  True  True  True False False  True
#   True  True False  True False  True  True  True  True False False False
#  False False  True False  True]
# # cust= 29
# Done  = False
# Total reward -561.0
# Action: 0
# Current Pos: [14  5]
# Next Post [19 15]
#  prev travel dist 561.0
# post travel dist 576.0
# Visited = [False False  True False  True False  True  True  True False False  True
#   True  True False  True False  True  True  True  True False False  True
#  False False  True False  True]
# # cust= 29
# Done  = False
# Total reward -576.0
# Action: 24
# Current Pos: [19 15]
# Next Post [ 5 30]
#  prev travel dist 576.0
# post travel dist 605.0
# Visited = [ True False  True False  True False  True  True  True False False  True
#   True  True False  True False  True  True  True  True False False  True
#  False False  True False  True]
# # cust= 29
# Done  = False
# Total reward -605.0
# Action: 22
# Current Pos: [ 5 30]
# Next Post [11 30]
#  prev travel dist 605.0
# post travel dist 611.0
# Visited = [ True False  True False  True False  True  True  True False False  True
#   True  True False  True False  True  True  True  True False False  True
#   True False  True False  True]
# # cust= 29
# Done  = False
# Total reward -611.0
# Action: 5
# Current Pos: [11 30]
# Next Post [8 5]
#  prev travel dist 611.0
# post travel dist 639.0
# Visited = [ True False  True False  True False  True  True  True False False  True
#   True  True False  True False  True  True  True  True False  True  True
#   True False  True False  True]
# # cust= 29
# Done  = False
# Total reward -639.0
# Action: 21
# Current Pos: [8 5]
# Next Post [44 22]
# ...
# post travel dist 554.0
# Visited = [ True  True False  True  True False  True False False False  True  True
#   True  True False  True  True False  True False False  True False  True
#  False  True  True False False]
# # cust= 29
# Done  = False
# Total reward -554.0
# Action: 20
# Current Pos: [36 20]
# Next Post [7 0]
#  prev travel dist 554.0
# post travel dist 603.0
# Visited = [ True  True False  True  True False  True False False False  True  True
#   True  True False  True  True False  True False False  True False  True
#  False  True  True False  True]
# # cust= 29
# Done  = False
# Total reward -603.0
# Action: 27
# Current Pos: [7 0]
# Next Post [ 8 45]
#  prev travel dist 603.0
# post travel dist 649.0
# Visited = [ True  True False  True  True False  True False False False  True  True
#   True  True False  True  True False  True False  True  True False  True
#  False  True  True False  True]
# # cust= 29
# Done  = False
# Total reward -649.0
# Action: 14
# Current Pos: [ 8 45]
# Next Post [40 20]
#  prev travel dist 649.0
# post travel dist 706.0
# Visited = [ True  True False  True  True False  True False False False  True  True
#   True  True False  True  True False  True False  True  True False  True
#  False  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -706.0
# Action: 9
# Current Pos: [40 20]
# Next Post [21 43]
#  prev travel dist 706.0
# post travel dist 748.0
# Visited = [ True  True False  True  True False  True False False False  True  True
#   True  True  True  True  True False  True False  True  True False  True
#  False  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -748.0
# Action: 8
# Current Pos: [21 43]
# Next Post [18 39]
#  prev travel dist 748.0
# post travel dist 755.0
# Visited = [ True  True False  True  True False  True False False  True  True  True
#   True  True  True  True  True False  True False  True  True False  True
#  False  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -755.0
# Action: 7
# Current Pos: [18 39]
# Next Post [11  8]
#  prev travel dist 755.0
# post travel dist 793.0
# Visited = [ True  True False  True  True False  True False  True  True  True  True
#   True  True  True  True  True False  True False  True  True False  True
#  False  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -793.0
# Action: 17
# Current Pos: [11  8]
# Next Post [47 37]
#  prev travel dist 793.0
# post travel dist 858.0
# Visited = [ True  True False  True  True False  True  True  True  True  True  True
#   True  True  True  True  True False  True False  True  True False  True
#  False  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -858.0
# Action: 19
# Current Pos: [47 37]
# Next Post [20  1]
#  prev travel dist 858.0
# post travel dist 921.0
# Visited = [ True  True False  True  True False  True  True  True  True  True  True
#   True  True  True  True  True  True  True False  True  True False  True
#  False  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -921.0
# Action: 22
# Current Pos: [20  1]
# Next Post [11 30]
#  prev travel dist 921.0
# post travel dist 959.0
# Visited = [ True  True False  True  True False  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True False  True
#  False  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -959.0
# Action: 24
# Current Pos: [11 30]
# Next Post [ 5 30]
#  prev travel dist 959.0
# post travel dist 965.0
# Visited = [ True  True False  True  True False  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -965.0
# Action: 2
# Current Pos: [ 5 30]
# Next Post [12 30]
#  prev travel dist 965.0
# post travel dist 972.0
# Visited = [ True  True False  True  True False  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -972.0
# Action: 5
# Current Pos: [12 30]
# Next Post [8 5]
#  prev travel dist 972.0
# post travel dist 1001.0
# Visited = [ True  True  True  True  True False  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -1001.0
# Action: 0
# Current Pos: [8 5]
# Next Post [19 15]
#  prev travel dist 1001.0
# post travel dist 1022.0
# Visited = [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = True
# SAC Agent - Invalid Route: Capacity constraint violated
# Action: 27
# Current Pos: [25. 25.]
# Next Post [ 8 45]
#  prev travel dist 0
# post travel dist 37.0
# Visited = [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False]
# # cust= 29
# Done  = False
# Total reward -37.0
# Action: 20
# Current Pos: [ 8 45]
# Next Post [7 0]
#  prev travel dist 37.0
# post travel dist 83.0
# Visited = [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False  True False]
# # cust= 29
# Done  = False
# Total reward -83.0
# Action: 9
# Current Pos: [7 0]
# Next Post [21 43]
#  prev travel dist 83.0
# post travel dist 140.0
# Visited = [False False False False False False False False False False False False
#  False False False False False False False False  True False False False
#  False False False  True False]
# # cust= 29
# Done  = False
# Total reward -140.0
# Action: 13
# Current Pos: [21 43]
# Next Post [26  0]
#  prev travel dist 140.0
# post travel dist 188.0
# Visited = [False False False False False False False False False  True False False
#  False False False False False False False False  True False False False
#  False False False  True False]
# # cust= 29
# Done  = False
# Total reward -188.0
# Action: 18
# Current Pos: [26  0]
# Next Post [21 13]
#  prev travel dist 188.0
# post travel dist 206.0
# Visited = [False False False False False False False False False  True False False
#  False  True False False False False False False  True False False False
#  False False False  True False]
# # cust= 29
# Done  = False
# Total reward -206.0
# Action: 1
# Current Pos: [21 13]
# Next Post [33 36]
#  prev travel dist 206.0
# post travel dist 241.0
# Visited = [False False False False False False False False False  True False False
#  False  True False False False False  True False  True False False False
#  False False False  True False]
# # cust= 29
# Done  = False
# Total reward -241.0
# Action: 8
# Current Pos: [33 36]
# Next Post [18 39]
#  prev travel dist 241.0
# post travel dist 259.0
# Visited = [False  True False False False False False False False  True False False
#  False  True False False False False  True False  True False False False
#  False False False  True False]
# # cust= 29
# Done  = False
# Total reward -259.0
# Action: 23
# Current Pos: [18 39]
# Next Post [14  5]
#  prev travel dist 259.0
# post travel dist 297.0
# Visited = [False  True False False False False False False  True  True False False
#  False  True False False False False  True False  True False False False
#  False False False  True False]
# # cust= 29
# Done  = False
# Total reward -297.0
# Action: 14
# Current Pos: [14  5]
# Next Post [40 20]
#  prev travel dist 297.0
# post travel dist 338.0
# Visited = [False  True False False False False False False  True  True False False
#  False  True False False False False  True False  True False False  True
#  False False False  True False]
# # cust= 29
# Done  = False
# Total reward -338.0
# Action: 11
# Current Pos: [40 20]
# Next Post [42 40]
#  prev travel dist 338.0
# post travel dist 360.0
# Visited = [False  True False False False False False False  True  True False False
#  False  True  True False False False  True False  True False False  True
#  False False False  True False]
# # cust= 29
# Done  = False
# Total reward -360.0
# Action: 25
# Current Pos: [42 40]
# Next Post [12 24]
#  prev travel dist 360.0
# post travel dist 406.0
# Visited = [False  True False False False False False False  True  True False  True
#  False  True  True False False False  True False  True False False  True
#  False False False  True False]
# # cust= 29
# Done  = False
# Total reward -406.0
# Action: 5
# Current Pos: [12 24]
# Next Post [8 5]
#  prev travel dist 406.0
# post travel dist 429.0
# Visited = [False  True False False False False False False  True  True False  True
#  False  True  True False False False  True False  True False False  True
#  False  True False  True False]
# # cust= 29
# Done  = False
# Total reward -429.0
# Action: 7
# Current Pos: [8 5]
# Next Post [11  8]
#  prev travel dist 429.0
# post travel dist 435.0
# Visited = [False  True False False False  True False False  True  True False  True
#  False  True  True False False False  True False  True False False  True
#  False  True False  True False]
# # cust= 29
# Done  = False
# Total reward -435.0
# Action: 24
# Current Pos: [11  8]
# Next Post [ 5 30]
#  prev travel dist 435.0
# post travel dist 463.0
# Visited = [False  True False False False  True False  True  True  True False  True
#  False  True  True False False False  True False  True False False  True
#  False  True False  True False]
# # cust= 29
# Done  = False
# Total reward -463.0
# Action: 2
# Current Pos: [ 5 30]
# Next Post [12 30]
#  prev travel dist 463.0
# post travel dist 470.0
# Visited = [False  True False False False  True False  True  True  True False  True
#  False  True  True False False False  True False  True False False  True
#   True  True False  True False]
# # cust= 29
# Done  = False
# Total reward -470.0
# Action: 17
# Current Pos: [12 30]
# Next Post [47 37]
#  prev travel dist 470.0
# post travel dist 512.0
# Visited = [False  True  True False False  True False  True  True  True False  True
#  False  True  True False False False  True False  True False False  True
#   True  True False  True False]
# # cust= 29
# Done  = False
# Total reward -512.0
# Action: 19
# Current Pos: [47 37]
# Next Post [20  1]
#  prev travel dist 512.0
# post travel dist 575.0
# Visited = [False  True  True False False  True False  True  True  True False  True
#  False  True  True False False  True  True False  True False False  True
#   True  True False  True False]
# # cust= 29
# Done  = False
# Total reward -575.0
# Action: 10
# Current Pos: [20  1]
# Next Post [49 14]
#  prev travel dist 575.0
# post travel dist 617.0
# Visited = [False  True  True False False  True False  True  True  True False  True
#  False  True  True False False  True  True  True  True False False  True
#   True  True False  True False]
# # cust= 29
# Done  = False
# Total reward -617.0
# Action: 28
# Current Pos: [49 14]
# Next Post [36 20]
#  prev travel dist 617.0
# post travel dist 636.0
# Visited = [False  True  True False False  True False  True  True  True  True  True
#  False  True  True False False  True  True  True  True False False  True
#   True  True False  True False]
# # cust= 29
# Done  = False
# Total reward -636.0
# Action: 3
# Current Pos: [36 20]
# Next Post [35 25]
#  prev travel dist 636.0
# post travel dist 642.0
# Visited = [False  True  True False False  True False  True  True  True  True  True
#  False  True  True False False  True  True  True  True False False  True
#   True  True False  True  True]
# # cust= 29
# Done  = False
# Total reward -642.0
# Action: 22
# Current Pos: [35 25]
# Next Post [11 30]
#  prev travel dist 642.0
# post travel dist 671.0
# Visited = [False  True  True  True False  True False  True  True  True  True  True
#  False  True  True False False  True  True  True  True False False  True
#   True  True False  True  True]
# # cust= 29
# Done  = False
# Total reward -671.0
# Action: 0
# Current Pos: [11 30]
# Next Post [19 15]
#  prev travel dist 671.0
# post travel dist 694.0
# Visited = [False  True  True  True False  True False  True  True  True  True  True
#  False  True  True False False  True  True  True  True False  True  True
#   True  True False  True  True]
# # cust= 29
# Done  = False
# Total reward -694.0
# Action: 15
# Current Pos: [19 15]
# Next Post [ 1 47]
#  prev travel dist 694.0
# post travel dist 744.0
# Visited = [ True  True  True  True False  True False  True  True  True  True  True
#  False  True  True False False  True  True  True  True False  True  True
#   True  True False  True  True]
# # cust= 29
# Done  = False
# Total reward -744.0
# Action: 4
# Current Pos: [ 1 47]
# Next Post [29 23]
#  prev travel dist 744.0
# post travel dist 796.0
# Visited = [ True  True  True  True False  True False  True  True  True  True  True
#  False  True  True  True False  True  True  True  True False  True  True
#   True  True False  True  True]
# # cust= 29
# Done  = False
# Total reward -796.0
# Action: 12
# Current Pos: [29 23]
# Next Post [10 41]
#  prev travel dist 796.0
# post travel dist 833.0
# Visited = [ True  True  True  True  True  True False  True  True  True  True  True
#  False  True  True  True False  True  True  True  True False  True  True
#   True  True False  True  True]
# # cust= 29
# Done  = False
# Total reward -833.0
# Action: 21
# Current Pos: [10 41]
# Next Post [44 22]
#  prev travel dist 833.0
# post travel dist 886.0
# Visited = [ True  True  True  True  True  True False  True  True  True  True  True
#   True  True  True  True False  True  True  True  True False  True  True
#   True  True False  True  True]
# # cust= 29
# Done  = False
# Total reward -886.0
# Action: 26
# Current Pos: [44 22]
# Next Post [22 11]
#  prev travel dist 886.0
# post travel dist 919.0
# Visited = [ True  True  True  True  True  True False  True  True  True  True  True
#   True  True  True  True False  True  True  True  True  True  True  True
#   True  True False  True  True]
# # cust= 29
# Done  = False
# Total reward -919.0
# Action: 16
# Current Pos: [22 11]
# Next Post [23  5]
#  prev travel dist 919.0
# post travel dist 926.0
# Visited = [ True  True  True  True  True  True False  True  True  True  True  True
#   True  True  True  True False  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -926.0
# Action: 6
# Current Pos: [23  5]
# Next Post [49 42]
#  prev travel dist 926.0
# post travel dist 989.0
# Visited = [ True  True  True  True  True  True False  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = False
# Total reward -989.0
# Action: 0
# Current Pos: [49 42]
# Next Post [19 15]
#  prev travel dist 989.0
# post travel dist 1046.0
# Visited = [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]
# # cust= 29
# Done  = True
# MaxEnt Agent - Invalid Route: Capacity constraint violated
#
# SAC Results:
#
# [] episode:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-ecc49d136789> in <cell line: 122>()
#     120 runner = RLExperimentRunner(env, sac_agent, maxent_agent, other_agents)
#     121 runner.run(episodes=50)
# --> 122 results = runner.summarize_results()
#
# <ipython-input-8-ecc49d136789> in summarize_results(self)
#      46             print(f"\n{name} Results:")
#      47             print(f"\n{tracker.episode_distances} episode:")
# ---> 48             stats = tracker.get_statistics()
#      49             print(f"Average Distance: {stats['avg_distance']:.2f}")
#      50             print(f"Best Distance: {stats['best_distance']:.2f}")
#
# <ipython-input-6-66c579d3084e> in get_statistics(self)
#     112             'best_route': self.best_route,
#     113             'avg_reward': np.mean(self.episode_rewards),
# --> 114             'completion_rate': len(valid_distances) / len(self.episode_distances),
#     115             'all_distances': self.episode_distances,
#     116             'all_rewards': self.episode_rewards
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Experiment on complex enviornment

# %%
# Experiment Setup
def run_experiments(episodes=100, env_size=10):
    # Initialize environment
    env = GymVRPEnvironment(num_customers=env_size)

    # Get actual state dimension from environment
    state = env.reset()
    state_dim = len(state)
    action_dim = env.action_space.n

    print(f"Environment initialized with state_dim={state_dim}, action_dim={action_dim}")

    # Initialize agents with correct dimensions
    maxent_agent = MaxEntRL(state_dim, action_dim, hidden_dim=256)
    sac_agent = SACAgent(state_dim, action_dim, hidden_dim=256)
    # dqn_agent = DQNAgent(state_dim, action_dim, hidden_dim=256)
    # nn_solver = NearestNeighbor()
    # ppo_env = GymVRPEnvironment(num_customers=env_size)
    # ppo_agent = PPOAgent(
    #     ppo_env,
    #     verbose=0,
    #     policy_kwargs={'net_arch': [256, 256]}
    # )
    # or_solver = ORToolsSolver()

    # # History tracking
    # or_rewards = []
    # ppo_rewards = []
    maxent_rewards = []
    sac_rewards = []
    # dqn_rewards = []
    # nn_rewards = []

    # Train PPO Agent
    print("\nTraining PPO...")
    # ppo_agent.model.learn(total_timesteps=episodes * 100)
    # ppo_agent.train(timesteps=episodes * 100)
    # Training loop
    for algorithm, agent, rewards in [
        ("MaxEnt", maxent_agent, maxent_rewards),
        ("SAC", sac_agent, sac_rewards),
        # ("DQN", dqn_agent, dqn_rewards),
    ]:
        print(f"\nTraining {algorithm}...")

        for episode in tqdm(range(episodes)):
            state = env.reset()
            episode_reward = 0
            steps = 0
            done = False

            while not done and steps < env_size * 2:
                steps += 1
                action = agent.select_action(state)
                next_state, reward, done, _ = env.step(action)

                agent.store_transition(state, action, reward, next_state, done)
                agent.update()

                episode_reward += reward
                state = next_state

            rewards.append(episode_reward)

            if (episode + 1) % 20 == 0:
                mean_reward = np.mean(rewards[-20:])
                print(f"\n{algorithm} Episode {episode+1}, Average Reward: {mean_reward:.2f}")

    # Run Nearest Neighbor
    # print("\nRunning Nearest Neighbor...")
    # for _ in tqdm(range(episodes)):
    #     reward = nn_solver.solve(env.env)
    #     nn_rewards.append(reward)

    # Run OR-Tools Solver
    # print("\nRunning OR-Tools Solver...")
    # for _ in tqdm(range(episodes)):
    #     reward = or_solver.solve(env.env)
    #     or_rewards.append(reward)

    # Evaluate PPO
    print("\nEvaluating PPO...")
    # ppo_rewards = ppo_agent.evaluate(episodes=episodes)

    return maxent_rewards, sac_rewards, maxent_agent, sac_agent
    # dqn_rewards, nn_rewards, or_rewards, ppo_rewards, maxent_rewards, sac_rewards, dqn_agent, maxent_agent, sac_agent, ppo_agent, nn_solver, or_solver

# Run and plot results
results = run_experiments()
# dqn_rewards, nn_rewards, or_rewards, ppo_rewards, maxent_rewards, sac_rewards, dqn_agent, maxent_agent, sac_agent, ppo_agent, nn_solver, or_solver
maxent_rewards, sac_rewards, maxent_agent, sac_agent = results

# Define methods to evaluate

methods = {
    #"DQN": lambda state: dqn_agent.select_action(state.numpy() if isinstance(state, torch.Tensor) else state),
    "MaxEnt": lambda state: maxent_agent.select_action(state.numpy() if isinstance(state, torch.Tensor) else state),
    "SAC": lambda state: sac_agent.select_action(state.numpy() if isinstance(state, torch.Tensor) else state),
    #"PPO": ppo_agent,
    #"Nearest Neighbor": lambda env: nn_solver.solve(env.env),
    #"OR-Tools": lambda env: or_solver.solve(env.env)
}
# Compute total distance and evaluate methods
def get_route_from_method(env, method_name, method_fn):
    """Helper function to get route from different methods"""
    env.reset()
    current_pos = env.env.depot.copy()
    route = []

    try:
        if method_name in ["DQN", "MaxEnt", "SAC"]:
            # For RL agents
            state = env.reset()
            done = False
            while not done and len(route) < env.env.num_customers:
                with torch.no_grad():
                    state_tensor = torch.FloatTensor(state).unsqueeze(0)
                    action = method_fn(state_tensor)
                    if isinstance(action, torch.Tensor):
                        action = action.item()
                next_state, _, done, _ = env.step(action)
                route.append(action)
                state = next_state
        elif method_name == "PPO":
            # For PPO
            state = env.reset()
            done = False
            while not done and len(route) < env.env.num_customers:
                action, _ = method_fn.model.predict(state)
                next_state, _, done, _ = env.step(action)
                route.append(int(action))
                state = next_state
        else:
            # For OR-Tools and Nearest Neighbor
            route = method_fn(env)

    except Exception as e:
        print(f"Error in {method_name}: {str(e)}")
        return None

    return route

import time

# def compute_route_distance(env, route):
#     """Compute total distance for a given route"""
#     if route is None:
#         return float('inf')

#     env.reset()
#     total_distance = 0
#     current_pos = env.env.depot.copy()

#     for action in route:
#         try:
#             if action < 0 or action >= env.env.num_customers or env.env.visited[action]:
#                 continue

#             next_pos = env.env.customers[action]
#             total_distance += np.linalg.norm(current_pos - next_pos)
#             current_pos = next_pos
#             env.env.visited[action] = True

#         except Exception as e:
#             print(f"Error computing distance for action {action}: {str(e)}")
#             return float('inf')

#     # Add return to depot
#     total_distance += np.linalg.norm(current_pos - env.env.depot)
#     return total_distance

# # def evaluate_distances(env, methods, episodes=10):
# #     """Evaluate methods over multiple episodes"""
# #     all_distances = {method: [] for method in methods.keys()}

# #     for episode in range(episodes):
# #         for method_name, method_fn in methods.items():
# #             route = get_route_from_method(env, method_name, method_fn)
# #             distance = compute_route_distance(env, route)
# #             all_distances[method_name].append(distance)

# #     # Compute averages
# #     avg_distances = {method: np.mean(distances) for method, distances in all_distances.items()}
# #     return avg_distances

# def compute_route_metrics(env, route):
#     """Compute both distance and constraint violations for a route"""
#     if route is None:
#         return {'distance': float('inf'), 'time_violations': 0, 'capacity_violations': 0}

#     env.reset()
#     total_distance = 0
#     current_time = 0
#     current_load = 0
#     current_pos = env.env.depot.copy()
#     time_window_violations = 0
#     capacity_violations = 0

#     for action in route:
#         try:
#             if action < 0 or action >= env.env.num_customers:
#                 continue

#             # Calculate distance and time
#             next_pos = env.env.customers[action]
#             travel_time = np.linalg.norm(current_pos - next_pos)
#             total_distance += travel_time

#             # Update time
#             current_time += travel_time

#             # Check time window violations
#             if current_time > env.env.due_times[action]:
#                 time_window_violations += 1
#             elif current_time < env.env.ready_times[action]:
#                 current_time = env.env.ready_times[action]

#             # Add service time
#             current_time += env.env.service_times[action]

#             # Check capacity violations
#             current_load += env.env.demands[action]
#             if current_load > env.env.vehicle_capacity:
#                 capacity_violations += 1

#             current_pos = next_pos

#         except Exception as e:
#             print(f"Error computing metrics for action {action}: {str(e)}")
#             return {'distance': float('inf'), 'time_violations': 0, 'capacity_violations': 0}

#     # Return to depot
#     total_distance += np.linalg.norm(current_pos - env.env.depot)

#     return {
#         'distance': total_distance,
#         'time_violations': time_window_violations,
#         'capacity_violations': capacity_violations
#     }

# def get_route_from_method(env, method_name, method_fn):
#     """Helper function to get route from different methods"""
#     env.reset()
#     route = []
#     visited_customers = set()

#     try:
#         if method_name in ["DQN", "MaxEnt", "SAC"]:
#             # For RL agents
#             state = env.reset()
#             done = False
#             steps = 0
#             max_steps = env.env.num_customers * 2  # Allow some buffer for mistakes

#             while not done and steps < max_steps:
#                 steps += 1
#                 with torch.no_grad():
#                     state_tensor = torch.FloatTensor(state).unsqueeze(0)
#                     action = method_fn(state_tensor)
#                     if isinstance(action, torch.Tensor):
#                         action = action.item()

#                 # Check if action is valid
#                 if action not in visited_customers and action < env.env.num_customers:
#                     route.append(action)
#                     visited_customers.add(action)

#                 next_state, _, done, _ = env.step(action)
#                 state = next_state

#                 # Check if all customers have been visited
#                 if len(visited_customers) == env.env.num_customers:
#                     done = True

#         elif method_name == "PPO":
#             # For PPO
#             state = env.reset()
#             done = False
#             steps = 0
#             max_steps = env.env.num_customers * 2

#             while not done and steps < max_steps:
#                 steps += 1
#                 action, _ = method_fn.model.predict(state)

#                 # Check if action is valid
#                 if action not in visited_customers and action < env.env.num_customers:
#                     route.append(int(action))
#                     visited_customers.add(action)

#                 next_state, _, done, _ = env.step(action)
#                 state = next_state

#                 # Check if all customers have been visited
#                 if len(visited_customers) == env.env.num_customers:
#                     done = True

#         else:
#             # For OR-Tools and Nearest Neighbor
#             route = method_fn(env)
#             visited_customers = set(route)

#         # Validate route
#         if len(visited_customers) != env.env.num_customers:
#             print(f"Warning: {method_name} did not visit all customers. Visited {len(visited_customers)}/{env.env.num_customers}")
#             return None

#     except Exception as e:
#         print(f"Error in {method_name}: {str(e)}")
#         return None

#     return route

def compute_route_metrics(env, route):
    """Compute both distance and constraint violations for a route"""
    if route is None:
        print("Route is None")
        return {'distance': float('inf'), 'time_violations': 0, 'capacity_violations': 0}

    env.reset()
    total_distance = 0
    current_time = 0
    current_load = 0
    current_pos = env.env.depot.copy()
    time_window_violations = 0
    capacity_violations = 0
    visited = set()

    # Check if all customers were visited
    if len(visited) != env.env.num_customers:
        return {'distance': float('inf'), 'time_violations': env.env.num_customers, 'capacity_violations': env.env.num_customers}

    # Return to depot
    total_distance += np.abs(current_pos - env.env.depot).sum()

    # Check final time window violation for depot return
    if current_time + np.abs(current_pos - env.env.depot).sum() > max(env.env.due_times):
        time_window_violations += 1

    return {
        'distance': total_distance,
        'time_violations': time_window_violations,
        'capacity_violations': capacity_violations
    }

def evaluate_methods_fairly(env, methods, episodes=10):
    """Evaluate all methods using the same metrics"""
    results = {method: {
        'distances': [],
        'time_violations': [],
        'capacity_violations': [],
        'execution_times': []
    } for method in methods.keys()}

    for episode in range(episodes):
        for method_name, method_fn in methods.items():
            start_time = time.time()
            route = get_route_from_method(env, method_name, method_fn)
            execution_time = time.time() - start_time

            metrics = compute_route_metrics(env, route)
            print("Dist",metrics['distance'])
            results[method_name]['distances'].append(metrics['distance'])
            results[method_name]['time_violations'].append(metrics['time_violations'])
            results[method_name]['capacity_violations'].append(metrics['capacity_violations'])
            results[method_name]['execution_times'].append(execution_time)

    # Create summary DataFrame using list comprehension instead of append
    summary_data = [
        {
            'Method': method,
            'Avg Distance': np.mean(results[method]['distances']),
            'Avg Time Violations': np.mean(results[method]['time_violations']),
            'Avg Capacity Violations': np.mean(results[method]['capacity_violations']),
            'Avg Execution Time (s)': np.mean(results[method]['execution_times'])
        }
        for method in results
    ]

    return pd.DataFrame(summary_data)

# # Evaluate distances
# print("\nEvaluating Total Distances...")
# avg_distances = evaluate_distances(GymVRPEnvironment(num_customers=10), methods)

# # Generate a table of results
# results_table = pd.DataFrame({
#     "Method": list(avg_distances.keys()),
#     "Average Distance": list(avg_distances.values())
# })
# print("\nResults Table:")
# print(results_table)

# Evaluate distances and times
print("\nEvaluating Performance...")
summary = evaluate_methods_fairly(GymVRPEnvironment(num_customers=100), methods)

# Generate a table of results
# results_table = pd.DataFrame({
#     "Method": list(avg_distances.keys()),
#     "Average Distance": list(avg_distances.values()),
#     "Average Time (s)": list(avg_times.values())
# })
print("\nResults Table:")
print(summary)

# Save results to CSV for analysis
summary.to_csv("vrp_performance.csv", index=False)
print("Performance results saved to 'vrp_performance.csv'.")

# Plotting
plt.figure(figsize=(15, 5))

# Raw rewards
plt.subplot(1, 2, 1)
plt.plot(maxent_rewards, label='MaxEnt', alpha=0.6)
plt.plot(sac_rewards, label='SAC', alpha=0.6)
plt.plot(dqn_rewards, label='DQN', alpha=0.6)
plt.plot(ppo_rewards, label='PPO', alpha=0.6)
plt.title('Training Rewards')
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.legend()

# Moving average
window = 20
plt.subplot(1, 2, 2)
plt.plot(np.convolve(maxent_rewards, np.ones(window)/window, mode='valid'),
         label='MaxEnt', alpha=0.8)
plt.plot(np.convolve(sac_rewards, np.ones(window)/window, mode='valid'),
         label='SAC', alpha=0.8)
plt.plot(np.convolve(dqn_rewards, np.ones(window)/window, mode='valid'),
         label='DQN', alpha=0.8)
plt.plot(np.convolve(ppo_rewards, np.ones(window)/window, mode='valid'),
         label='PPO', alpha=0.8)
plt.title(f'Moving Average ({window} episodes)')
plt.xlabel('Episode')
plt.ylabel('Average Reward')
plt.legend()

plt.tight_layout()
plt.show()

# Print final statistics
def print_stats(rewards, name):
    print(f"\n{name} Statistics:")
    print(f"Final Average (last 20 episodes): {np.mean(rewards[-20:]):.2f}")
    print(f"Best Episode: {max(rewards):.2f}")
    print(f"Worst Episode: {min(rewards):.2f}")
    print(f"Overall Average: {np.mean(rewards):.2f}")
# Keep all previous code the same until the plotting section, then replace with:

def plot_comparison(maxent_rewards, sac_rewards, dqn_rewards, ppo_rewards, window=10):
    plt.figure(figsize=(15, 5))

    # Get number of episodes
    episodes = len(maxent_rewards)
    x_axis = np.arange(episodes)

    # Raw rewards
    plt.subplot(1, 2, 1)
    plt.plot(x_axis, maxent_rewards, label='MaxEnt', alpha=0.6)
    plt.plot(x_axis, sac_rewards, label='SAC', alpha=0.6)
    plt.plot(x_axis, dqn_rewards, label='DQN', alpha=0.6)
    plt.plot(x_axis, ppo_rewards, label='PPO', alpha=0.6)
    plt.title('Training Rewards (Raw)')
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.legend()
    plt.grid(True, alpha=0.3)

    # Moving average
    def get_moving_average(rewards, window):
        weights = np.ones(window) / window
        return np.convolve(rewards, weights, mode='valid')

    # Calculate moving averages
    ma_maxent = get_moving_average(maxent_rewards, window)
    ma_sac = get_moving_average(sac_rewards, window)
    ma_dqn = get_moving_average(dqn_rewards, window)
    ma_ppo = get_moving_average(ppo_rewards, window)

    # Adjust x-axis for moving average plot to align with original episodes
    ma_x = np.arange(window-1, episodes)

    plt.subplot(1, 2, 2)
    plt.plot(ma_x, ma_maxent, label='MaxEnt', alpha=0.8)
    plt.plot(ma_x, ma_sac, label='SAC', alpha=0.8)
    plt.plot(ma_x, ma_dqn, label='DQN', alpha=0.8)
    plt.plot(ma_x, ma_ppo, label='PPO', alpha=0.8)
    plt.title(f'Training Rewards ({window}-Episode Moving Average)')
    plt.xlabel('Episode')
    plt.ylabel('Average Reward')
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# After training, call the plotting function with a smaller window
print("Plotting results...")
plot_comparison(maxent_rewards, sac_rewards, dqn_rewards, ppo_rewards, window=10)  # Changed to 10-episode window

# Print statistics with both raw and smoothed metrics
def print_stats(rewards, name, window=10):
    print(f"\n{name} Statistics:")
    print(f"Raw Metrics:")
    print(f"Final Average (last {window} episodes): {np.mean(rewards[-window:]):.2f}")
    print(f"Best Episode: {max(rewards):.2f}")
    print(f"Worst Episode: {min(rewards):.2f}")
    print(f"Overall Average: {np.mean(rewards):.2f}")
    def get_moving_average(rewards, window):
        weights = np.ones(window) / window
        return np.convolve(rewards, weights, mode='valid')
    # Smoothed metrics
    smoothed = get_moving_average(rewards, window)
    print(f"\nSmoothed Metrics ({window}-episode window):")
    print(f"Best Smoothed Performance: {max(smoothed):.2f}")
    print(f"Final Smoothed Performance: {smoothed[-1]:.2f}")

print("\nPerformance Statistics:")
print_stats(maxent_rewards, "MaxEnt")
print_stats(sac_rewards, "SAC")
print_stats(dqn_rewards, "DQN")

# Bar chart for solution quality comparison
methods = ["DQN", "Nearest Neighbor", "OR-Tools", "PPO"]
average_rewards = [np.mean(dqn_rewards), np.mean(nn_rewards), np.mean(or_rewards), np.mean(ppo_rewards)]

plt.figure(figsize=(8, 5))
plt.bar(methods, average_rewards, color=['blue', 'orange', 'green', 'purple'])
plt.xlabel("Method")
plt.ylabel("Average Reward (Solution Quality)")
plt.title("Solution Quality Comparison")
plt.show()

test_env = GymVRPEnvironment(num_customers=10)

print("\nEvaluating Total Distances...")
avg_distances = evaluate_distances(test_env, methods)

print("\nDistances Table:")
distances_df = pd.DataFrame({
    "Method": list(avg_distances.keys()),
    "Average Distance": list(avg_distances.values())
})
print(distances_df)

print("\nEvaluating Performance...")
avg_distances, avg_times = evaluate_performance(test_env, methods)

print("\nPerformance Table:")
performance_df = pd.DataFrame({
    "Method": list(avg_distances.keys()),
    "Average Distance": list(avg_distances.values()),
    "Average Time (s)": list(avg_times.values())
})
print(performance_df)

def visualize_routes(env, methods):
    plt.figure(figsize=(12, 8))
    depot = env.env.depot
    customers = env.env.customers

    for method, action_fn in methods.items():
        env.reset()
        actions = action_fn(env)
        route = [depot] + [customers[a] for a in actions if isinstance(a, int) and 0 <= a < len(customers)] + [depot]
        route = np.array(route)

        plt.plot(route[:, 0], route[:, 1], marker='o', label=method)
        plt.scatter(depot[0], depot[1], c='red', s=100, label='Depot')

    plt.title("Routes Generated by Different Methods")
    plt.xlabel("X-coordinate")
    plt.ylabel("Y-coordinate")
    plt.legend()
    plt.grid(True)
    plt.show()

visualize_routes(GymVRPEnvironment(num_customers=100), methods)

# Save results to CSV
data = {
    "DQN Rewards": dqn_rewards,
    "Nearest Neighbor Rewards": nn_rewards,
    "OR-Tools Rewards": or_rewards,
    "PPO Rewards": ppo_rewards
}
df = pd.DataFrame(data)
df.to_csv("vrp_results.csv", index=False)
print("Results saved to 'vrp_results.csv'.")

# %% [markdown]
# Test on Solomon data

# %%
def load_solomon_c101(file_path):
    """Load and process Solomon C101 dataset"""
    try:
        solomon_data = parse_solomon_dataset(file_path)

        # Create environment with Solomon data
        env = GymVRPEnvironment(solomon_data=solomon_data)
        return env

    except Exception as e:
        print(f"Error loading Solomon dataset: {str(e)}")
        return None

def run_solomon_experiments(file_path, episodes=1000):
    """Run experiments using Solomon dataset"""
    # Load environment with Solomon data
    env = load_solomon_c101(file_path)
    if env is None:
        return None

    # Get state and action dimensions from environment
    state = env.reset()
    state_dim = len(state)
    action_dim = env.action_space.n

    print(f"Solomon Environment initialized with:")
    print(f"- Number of customers: {env.env.num_customers}")
    print(f"- State dimension: {state_dim}")
    print(f"- Action dimension: {action_dim}")

    # Initialize agents
    maxent_agent = MaxEntRL(state_dim, action_dim, hidden_dim=256)
    sac_agent = SACAgent(state_dim, action_dim, hidden_dim=256)
    dqn_agent = DQNAgent(state_dim, action_dim, hidden_dim=256)
    nn_solver = NearestNeighbor()
    ppo_env = load_solomon_c101(file_path)  # Create separate env for PPO
    ppo_agent = PPOAgent(
        ppo_env,
        verbose=0,
        policy_kwargs={'net_arch': [256, 256]}
    )
    or_solver = ORToolsSolver()

    # History tracking
    or_rewards = []
    ppo_rewards = []
    maxent_rewards = []
    sac_rewards = []
    dqn_rewards = []
    nn_rewards = []

    # Train PPO Agent
    print("\nTraining PPO...")
    ppo_agent.train(timesteps=episodes * 100)

    # Training loop for other RL agents
    for algorithm, agent, rewards in [
        ("MaxEnt", maxent_agent, maxent_rewards),
        ("SAC", sac_agent, sac_rewards),
        ("DQN", dqn_agent, dqn_rewards),
    ]:
        print(f"\nTraining {algorithm}...")

        for episode in tqdm(range(episodes)):
            state = env.reset()
            episode_reward = 0
            steps = 0
            done = False

            while not done and steps < env.env.num_customers * 2:
                steps += 1
                action = agent.select_action(state)
                next_state, reward, done, _ = env.step(action)

                agent.store_transition(state, action, reward, next_state, done)
                agent.update()

                episode_reward += reward
                state = next_state

            rewards.append(episode_reward)

            if (episode + 1) % 20 == 0:
                mean_reward = np.mean(rewards[-20:])
                print(f"\n{algorithm} Episode {episode+1}, Average Reward: {mean_reward:.2f}")

    # Evaluate heuristic methods
    print("\nRunning Nearest Neighbor...")
    for _ in tqdm(range(episodes)):
        route = nn_solver.solve(env.env)
        metrics = compute_route_metrics(env, route)
        nn_rewards.append(-metrics['distance'])  # Convert distance to reward

    print("\nRunning OR-Tools Solver...")
    for _ in tqdm(range(episodes)):
        route = or_solver.solve(env.env)
        metrics = compute_route_metrics(env, route)
        or_rewards.append(-metrics['distance'])  # Convert distance to reward

    # Evaluate PPO
    print("\nEvaluating PPO...")
    ppo_rewards = ppo_agent.evaluate(episodes=episodes)

    return {
        'env': env,
        'rewards': {
            'DQN': dqn_rewards,
            'MaxEnt': maxent_rewards,
            'SAC': sac_rewards,
            'PPO': ppo_rewards,
            'Nearest Neighbor': nn_rewards,
            'OR-Tools': or_rewards
        },
        'agents': {
            'DQN': dqn_agent,
            'MaxEnt': maxent_agent,
            'SAC': sac_agent,
            'PPO': ppo_agent,
            'Nearest Neighbor': nn_solver,
            'OR-Tools': or_solver
        }
    }

# Usage example:
file_path = '/content/c101.txt'
results = run_solomon_experiments(file_path, episodes=1000)

if results:
    env = results['env']
    rewards = results['rewards']
    agents = results['agents']

    # Evaluate methods using fair comparison
    methods = {
        "DQN": lambda state: agents['DQN'].select_action(state.numpy() if isinstance(state, torch.Tensor) else state),
        "MaxEnt": lambda state: agents['MaxEnt'].select_action(state.numpy() if isinstance(state, torch.Tensor) else state),
        "SAC": lambda state: agents['SAC'].select_action(state.numpy() if isinstance(state, torch.Tensor) else state),
        "PPO": agents['PPO'],
        "Nearest Neighbor": lambda env: agents['Nearest Neighbor'].solve(env.env),
        "OR-Tools": lambda env: agents['OR-Tools'].solve(env.env)
    }

    # Evaluate performance
    print("\nEvaluating Performance...")
    summary = evaluate_methods_fairly(env, methods)
    print("\nResults Summary:")
    print(summary)

    # Plot results
    plot_comparison(
        rewards['MaxEnt'],
        rewards['SAC'],
        rewards['DQN'],
        rewards['PPO'],
        window=10
    )

    # Visualize routes
    visualize_routes(env, methods)
